# %%
import pandas as pd
import os
import json
import time
from datetime import datetime

import pandas as pd
import numpy as np

import tiktoken
import gzip
from openai import OpenAI
import json
import time
from datetime import datetime

import pandas as pd
import numpy as np

import tiktoken
import gzip
from openai import OpenAI

v9_df = pd.read_parquet("/home/mads/connectome/data/predictions/v9_full_output_20250327_134335.parquet")
v8_df = pd.read_parquet("/home/mads/connectome/data/predictions/v8_full_output_20250327_132426.parquet")

# %%
v9_df
# Out:
#            id                                          embedding
# 0           0  {"0":[["**[organ] correlated with [metabolite]...
# 1           1  {"1":[["[organ] mediates [metabolite]","[organ...
# 2           2  {"2":[["**[organ] leads to [metabolite]**","[o...
# 3           3  {"3":[["**[organ] affects [metabolite]**","[or...
# 4           4  {"4":[["**[organ] is related to [metabolite]**...
# ...       ...                                                ...
# 98555  116971  {"116971":[["**[gene] are classified into [pro...
# 98556  116972  {"116972":[["**[gene] differ in [protein domai...
# 98557  116973  {"116973":[["[gene] evolved to [protein domain...
# 98558  116974  {"116974":[["[gene] predict [protein domain]",...
# 98559  116975  {"116975":[["**[gene] divided into [protein do...
#
# [98560 rows x 2 columns]

# %%
v9_df
# Out:
#            id                                          embedding
# 0           0  {"0":[["**[organ] correlated with [metabolite]...
# 1           1  {"1":[["[organ] mediates [metabolite]","[organ...
# 2           2  {"2":[["**[organ] leads to [metabolite]**","[o...
# 3           3  {"3":[["**[organ] affects [metabolite]**","[or...
# 4           4  {"4":[["**[organ] is related to [metabolite]**...
# ...       ...                                                ...
# 98555  116971  {"116971":[["**[gene] are classified into [pro...
# 98556  116972  {"116972":[["**[gene] differ in [protein domai...
# 98557  116973  {"116973":[["[gene] evolved to [protein domain...
# 98558  116974  {"116974":[["[gene] predict [protein domain]",...
# 98559  116975  {"116975":[["**[gene] divided into [protein do...
#
# [98560 rows x 2 columns]

# %%
v9_df.
# Out:
#   Cell In[15], line 1
#     v9_df.
#           ^
# SyntaxError: invalid syntax
