# %%
import os
import json
import time
from datetime import datetime

import pandas as pd
#display all columns
pd.set_option('display.max_columns', None)
import numpy as np

import tiktoken
import gzip
from openai import OpenAI

# %%
def load_output_jsonl(file_path):
    # Read the JSONL file and parse each line as JSON
    print(file_path)
    with open(file_path, 'rt') as f:  
        data = []
        for line in f:

                json_obj = json.loads(line)
                embedding = json_obj['response']['body']['choices'][0]['message']['content']
                data.append({
                    'id': json_obj['custom_id'],
                    'embedding': embedding
                })

    # Convert to DataFrame
    df = pd.DataFrame(data)
    return df


def test_output(output_df: pd.DataFrame):
    output_df.rename(columns={'embedding': 'output_string'}, inplace=True)

    cluster_df = pd.read_parquet('/home/mads/connectome/data/embeddings/edge_embeddings/clustering/edge_clusters_6_max_clust_30.parquet')
    cluster_df = cluster_df[cluster_df.cluster_size > 1]
    
    print(len(cluster_df))

    #create the input string. the string should be "index: the list of edges as a string"
    cluster_df["input"] = cluster_df.apply(lambda row: f"{row.name}: {row['ids_in_cluster']}", axis=1)

    cluster_df["id"] = cluster_df["cluster_id"].astype(str)
    merged_df = pd.merge(output_df, cluster_df[["id", "ids_in_cluster"]], on='id', how='inner')


    # evaluate the dictionary strings in o3_output and finetuned_output
    def load_dict(dict_string):
        try:
            return json.loads(dict_string)
        except Exception as e:
            #print(f"Failed to parse {dict_string}")
            #print(e)
            return []


    merged_df["finetuned_output"] = merged_df["output_string"].apply(load_dict)

    merged_df["finetuned_output_parsed"] = merged_df["finetuned_output"].apply(lambda x: isinstance(x, dict))

    
    print(merged_df["finetuned_output_parsed"].value_counts())

    rerun_df = merged_df[merged_df["finetuned_output_parsed"] == False]

    merged_df = merged_df[merged_df["finetuned_output_parsed"] == True]





    def convert_to_list(row):
        try:
            return eval(list(row.values())[0])
        except:
            #print(row)
            return None

    merged_df["finetuned_list"] = merged_df["finetuned_output"].apply(convert_to_list)
    #if "finetuned_list" is a tuple, take the first element
    merged_df["finetuned_list"] = merged_df["finetuned_list"].apply(lambda x: x[0] if isinstance(x, tuple) else x)

    #add merged_df["finetuned_list"].isnull() to needs_rerun and remove rows from merged_df where finetuned_list is None
    rerun_df = pd.concat([rerun_df.copy(), merged_df[merged_df["finetuned_list"].isnull()]].copy())
    merged_df = merged_df[merged_df["finetuned_list"].notnull()]

    print("length of mergeed_df:",  len(merged_df))
    print("length of rerun:",len(rerun_df))
    #flatten the list



    merged_df["flattened_list"] = merged_df["finetuned_list"].apply(lambda x: [item for sublist in x for item in sublist])

    def flatten_list_to_strings(item):
        """
        Recursively flatten a nested structure (lists/tuples) into a single list of strings.
        Non-string items will be converted to strings.
        
        Args:
            item: Any Python object that might contain nested lists/tuples
            
        Returns:
            list: A flattened list containing only strings
        """
        if isinstance(item, (list, tuple)):
            return [
                str_item 
                for sublist in item 
                for str_item in flatten_list_to_strings(sublist)
            ]
        else:
            return [str(item)]

    # You can then replace your assertions with:
    merged_df["flattened_list"] = merged_df["flattened_list"].apply(flatten_list_to_strings)



    #check that the flattened list is flattened, by checking that all entries are strings
    assert merged_df["flattened_list"].apply(lambda x: isinstance(x, list)).all()
    assert merged_df["flattened_list"].apply(lambda x: all(isinstance(item, str) for item in x)).all()

    def check_if_outputs_matches_input(row):
        flattened_list = row["flattened_list"]
        checks = []
        
        for item in flattened_list:
            try:
                if item.strip("*: ") in row["ids_in_cluster"]:
                    checks.append(True)
                else:
                    checks.append(False)
            except:
                print("error")
                print(item)
                print("flattened_list:", flattened_list)
                print("output")
                
                checks.append(False)
        if False in checks:
            return False
        else:
            return True

    merged_df["output_matches_input"] = merged_df.apply(check_if_outputs_matches_input, axis=1)





    def check_if_representative_is_in_finetuned_list(row):
        list_of_checks = []
        for item in row["finetuned_list"]:
            group_has_representative = False
            for entry in item:
                if "**" in entry:
                    group_has_representative = True
        
            list_of_checks.append(group_has_representative)
        if False in list_of_checks:
            return False
        else:
            return True
        

    def check_that_all_edges_have_same_types(row):
        
        for item in row["finetuned_list"]:
            #print(item)
            source_types = set()
            target_types = set()
            for edge in item:
                edge = edge.strip("*: ")
                try:
                    source_type = edge.split("]")[0].split("[")[1]
                    target_type = edge.split("[")[2].split("]")[0]
                    source_types.add(source_type)
                    target_types.add(target_type)
                except:
                    print(edge)
            if len(source_types) > 1 or len(target_types) > 1:

                return False
        return True


    def check_that_all_edges_have_same_types(row):
        for item in row["finetuned_list"]:
            source_types = set()
            target_types = set()
            for edge in item:
                # Handle case where edge might be a list or string
                if isinstance(edge, list):
                    # If it's a list, skip it or handle it appropriately
                    continue
                
                edge_str = edge.strip("*: ")
                try:
                    source_type = edge_str.split("]")[0].split("[")[1]
                    target_type = edge_str.split("[")[2].split("]")[0]
                    source_types.add(source_type)
                    target_types.add(target_type)
                except:
                    print(f"Error processing edge: {edge}")
                    continue
                    
            if len(source_types) > 1 or len(target_types) > 1:
                return False
        return True



    merged_df["finetuned_representative_in_list"] = merged_df.apply(check_if_representative_is_in_finetuned_list, axis=1)
    merged_df["all_edges_have_same_types"] = merged_df.apply(check_that_all_edges_have_same_types, axis=1)
    return merged_df, rerun_df




output_df = pd.read_parquet('/home/mads/connectome/data/predictions/v8_full_output_20250331_141507.parquet')

merged_df, rerun_df = test_output(output_df)
# Out:
# 98560
# finetuned_output_parsed
# True     98491
# False       69
# Name: count, dtype: int64
# length of mergeed_df: 98120
# length of rerun: 440
# Error processing edge: [
# Error processing edge: [
# Error processing edge: m
# Error processing edge: e
# Error processing edge: t
# Error processing edge: a
# Error processing edge: b
# Error processing edge: o
# Error processing edge: l
# Error processing edge: i
# Error processing edge: t
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: s
# Error processing edge: p
# Error processing edge: e
# Error processing edge: e
# Error processing edge: d
# Error processing edge: s
# Error processing edge:
# Error processing edge: u
# Error processing edge: p
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: m
# Error processing edge: e
# Error processing edge: t
# Error processing edge: a
# Error processing edge: b
# Error processing edge: o
# Error processing edge: l
# Error processing edge: i
# Error processing edge: t
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: s
# Error processing edge: p
# Error processing edge: e
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: u
# Error processing edge: p
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: m
# Error processing edge: e
# Error processing edge: t
# Error processing edge: a
# Error processing edge: b
# Error processing edge: o
# Error processing edge: l
# Error processing edge: i
# Error processing edge: t
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: i
# Error processing edge: m
# Error processing edge: p
# Error processing edge: a
# Error processing edge: i
# Error processing edge: r
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: m
# Error processing edge: e
# Error processing edge: t
# Error processing edge: a
# Error processing edge: b
# Error processing edge: o
# Error processing edge: l
# Error processing edge: i
# Error processing edge: t
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: c
# Error processing edge: o
# Error processing edge: u
# Error processing edge: l
# Error processing edge: d
# Error processing edge:
# Error processing edge: i
# Error processing edge: m
# Error processing edge: p
# Error processing edge: a
# Error processing edge: i
# Error processing edge: r
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: m
# Error processing edge: e
# Error processing edge: t
# Error processing edge: a
# Error processing edge: b
# Error processing edge: o
# Error processing edge: l
# Error processing edge: i
# Error processing edge: t
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: b
# Error processing edge: l
# Error processing edge: o
# Error processing edge: c
# Error processing edge: k
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: [
# Error processing edge: s
# Error processing edge: u
# Error processing edge: b
# Error processing edge: c
# Error processing edge: e
# Error processing edge: l
# Error processing edge: l
# Error processing edge: u
# Error processing edge: l
# Error processing edge: a
# Error processing edge: r
# Error processing edge:
# Error processing edge: c
# Error processing edge: o
# Error processing edge: m
# Error processing edge: p
# Error processing edge: a
# Error processing edge: r
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: m
# Error processing edge: e
# Error processing edge: t
# Error processing edge: a
# Error processing edge: b
# Error processing edge: o
# Error processing edge: l
# Error processing edge: i
# Error processing edge: t
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: b
# Error processing edge: l
# Error processing edge: o
# Error processing edge: c
# Error processing edge: k
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: b
# Error processing edge: y
# Error processing edge:
# Error processing edge: [
# Error processing edge: s
# Error processing edge: u
# Error processing edge: b
# Error processing edge: c
# Error processing edge: e
# Error processing edge: l
# Error processing edge: l
# Error processing edge: u
# Error processing edge: l
# Error processing edge: a
# Error processing edge: r
# Error processing edge:
# Error processing edge: c
# Error processing edge: o
# Error processing edge: m
# Error processing edge: p
# Error processing edge: a
# Error processing edge: r
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: m
# Error processing edge: e
# Error processing edge: t
# Error processing edge: a
# Error processing edge: b
# Error processing edge: o
# Error processing edge: l
# Error processing edge: i
# Error processing edge: t
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: d
# Error processing edge: e
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: m
# Error processing edge: i
# Error processing edge: n
# Error processing edge: e
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: s
# Error processing edge: u
# Error processing edge: b
# Error processing edge: c
# Error processing edge: e
# Error processing edge: l
# Error processing edge: l
# Error processing edge: u
# Error processing edge: l
# Error processing edge: a
# Error processing edge: r
# Error processing edge:
# Error processing edge: c
# Error processing edge: o
# Error processing edge: m
# Error processing edge: p
# Error processing edge: a
# Error processing edge: r
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: m
# Error processing edge: e
# Error processing edge: t
# Error processing edge: a
# Error processing edge: b
# Error processing edge: o
# Error processing edge: l
# Error processing edge: i
# Error processing edge: t
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: d
# Error processing edge: e
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: m
# Error processing edge: i
# Error processing edge: n
# Error processing edge: e
# Error processing edge:
# Error processing edge: [
# Error processing edge: s
# Error processing edge: u
# Error processing edge: b
# Error processing edge: c
# Error processing edge: e
# Error processing edge: l
# Error processing edge: l
# Error processing edge: u
# Error processing edge: l
# Error processing edge: a
# Error processing edge: r
# Error processing edge:
# Error processing edge: c
# Error processing edge: o
# Error processing edge: m
# Error processing edge: p
# Error processing edge: a
# Error processing edge: r
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: consistent with [tissue]
# Error processing edge: behaving in a similar way across [tissue]
# Error processing edge: are similar in [tissue]
# Error processing edge: is similar in [tissue]
# Error processing edge: converges to [tissue]
# Error processing edge: identical in [tissue]
# Error processing edge: similar between [tissue]
# Error processing edge: equivalent to [tissue]
# Error processing edge: homogenous in [tissue]
# Error processing edge: equal in [tissue]
# Error processing edge: has equal transcript levels in [tissue]
# Error processing edge: show strong conservation of [tissue]
# Error processing edge: decrease during [treatment]
# Error processing edge: decrease with [treatment]
# Error processing edge: decrease under [treatment]
# Error processing edge: decrease upon [treatment]
# Error processing edge: decrease at [treatment]
# Error processing edge: decreases as [treatment]
# Error processing edge: decreases due to [treatment]
# Error processing edge: decreasing in abundance at [treatment]
# Error processing edge: decrease after [treatment]
# Error processing edge: decreases in abundance after [treatment]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge:
# Error processing edge: e
# Error processing edge: n
# Error processing edge: c
# Error processing edge: a
# Error processing edge: p
# Error processing edge: s
# Error processing edge: u
# Error processing edge: l
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: [
# Error processing edge: g
# Error processing edge: e
# Error processing edge: n
# Error processing edge: e
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge:
# Error processing edge: e
# Error processing edge: n
# Error processing edge: c
# Error processing edge: a
# Error processing edge: p
# Error processing edge: s
# Error processing edge: u
# Error processing edge: l
# Error processing edge: a
# Error processing edge: t
# Error processing edge: i
# Error processing edge: n
# Error processing edge: g
# Error processing edge:
# Error processing edge: [
# Error processing edge: g
# Error processing edge: e
# Error processing edge: n
# Error processing edge: e
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [gene] influences genomic region]
# Error processing edge: interconnect with [gene]
# Error processing edge: interact cooperatively with [gene]
# Error processing edge: closely cooperates with [gene]
# Error processing edge: interacts and cooperates with [gene]
# Error processing edge: contribute cooperatively with [gene]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: g
# Error processing edge: e
# Error processing edge: n
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: h
# Error processing edge: i
# Error processing edge: g
# Error processing edge: h
# Error processing edge: l
# Error processing edge: i
# Error processing edge: g
# Error processing edge: h
# Error processing edge: t
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: g
# Error processing edge: e
# Error processing edge: n
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: i
# Error processing edge: l
# Error processing edge: l
# Error processing edge: u
# Error processing edge: m
# Error processing edge: i
# Error processing edge: n
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: a
# Error processing edge: r
# Error processing edge: a
# Error processing edge: m
# Error processing edge: e
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: ]
# Error processing edge:
# Error processing edge: i
# Error processing edge: d
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: i
# Error processing edge: f
# Error processing edge: i
# Error processing edge: e
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: g
# Error processing edge: e
# Error processing edge: n
# Error processing edge: e
# Error processing edge:
# Error processing edge: f
# Error processing edge: a
# Error processing edge: m
# Error processing edge: i
# Error processing edge: l
# Error processing edge: y
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: a
# Error processing edge: r
# Error processing edge: a
# Error processing edge: m
# Error processing edge: e
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: ]
# Error processing edge:
# Error processing edge: i
# Error processing edge: d
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: i
# Error processing edge: f
# Error processing edge: y
# Error processing edge: i
# Error processing edge: n
# Error processing edge: g
# Error processing edge:
# Error processing edge: [
# Error processing edge: g
# Error processing edge: e
# Error processing edge: n
# Error processing edge: e
# Error processing edge:
# Error processing edge: f
# Error processing edge: a
# Error processing edge: m
# Error processing edge: i
# Error processing edge: l
# Error processing edge: y
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: decline [organ]
# Error processing edge: virtually no expression in [organ]
# Error processing edge: shortly after [phenotype]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: s
# Error processing edge: u
# Error processing edge: p
# Error processing edge: p
# Error processing edge: o
# Error processing edge: r
# Error processing edge: t
# Error processing edge:
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: s
# Error processing edge: u
# Error processing edge: p
# Error processing edge: p
# Error processing edge: o
# Error processing edge: r
# Error processing edge: t
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: r
# Error processing edge: e
# Error processing edge: c
# Error processing edge: e
# Error processing edge: i
# Error processing edge: v
# Error processing edge: e
# Error processing edge:
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: g
# Error processing edge: i
# Error processing edge: v
# Error processing edge: e
# Error processing edge:
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: b
# Error processing edge: e
# Error processing edge: a
# Error processing edge: r
# Error processing edge:
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: f
# Error processing edge: a
# Error processing edge: c
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: w
# Error processing edge: i
# Error processing edge: t
# Error processing edge: h
# Error processing edge:
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: no difference in [mutant]
# Error processing edge: show no dramatic differences in [mutant]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge:
# Error processing edge: m
# Error processing edge: a
# Error processing edge: n
# Error processing edge: i
# Error processing edge: f
# Error processing edge: e
# Error processing edge: s
# Error processing edge: t
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: share characteristics with [organism]
# Error processing edge: show improvement of [phenotype]
# Error processing edge: improvement of [phenotype]
# Error processing edge: show improvement in [phenotype]
# Error processing edge: altered in [phenotype]
# Error processing edge: has altered [phenotype]
# Error processing edge: shows altered [phenotype]
# Error processing edge: with altered [phenotype]
# Error processing edge: altering its [phenotype]
# Error processing edge: deforms upon [phenotype]
# Error processing edge: drastically alters [phenotype]
# Error processing edge: altered their [phenotype]
# Error processing edge: prime constituents of [organ]
# Error processing edge: might differ from [organism]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: t
# Error processing edge: i
# Error processing edge: s
# Error processing edge: s
# Error processing edge: u
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: s
# Error processing edge: e
# Error processing edge: r
# Error processing edge: v
# Error processing edge: e
# Error processing edge: s
# Error processing edge:
# Error processing edge: a
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: t
# Error processing edge: i
# Error processing edge: s
# Error processing edge: s
# Error processing edge: u
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: a
# Error processing edge: c
# Error processing edge: t
# Error processing edge: s
# Error processing edge:
# Error processing edge: a
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: w
# Error processing edge: a
# Error processing edge: s
# Error processing edge:
# Error processing edge: u
# Error processing edge: s
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: t
# Error processing edge: o
# Error processing edge:
# Error processing edge: s
# Error processing edge: y
# Error processing edge: n
# Error processing edge: t
# Error processing edge: h
# Error processing edge: e
# Error processing edge: s
# Error processing edge: i
# Error processing edge: z
# Error processing edge: e
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: s
# Error processing edge: y
# Error processing edge: n
# Error processing edge: t
# Error processing edge: h
# Error processing edge: e
# Error processing edge: s
# Error processing edge: i
# Error processing edge: z
# Error processing edge: e
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: t
# Error processing edge: a
# Error processing edge: r
# Error processing edge: g
# Error processing edge: e
# Error processing edge: t
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: e
# Error processing edge: x
# Error processing edge: p
# Error processing edge: l
# Error processing edge: o
# Error processing edge: i
# Error processing edge: t
# Error processing edge: i
# Error processing edge: n
# Error processing edge: g
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: i
# Error processing edge: n
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: n
# Error processing edge: a
# Error processing edge: l
# Error processing edge: i
# Error processing edge: z
# Error processing edge: e
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: s
# Error processing edge: e
# Error processing edge: q
# Error processing edge: u
# Error processing edge: e
# Error processing edge: s
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: c
# Error processing edge: l
# Error processing edge: e
# Error processing edge: a
# Error processing edge: r
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: r
# Error processing edge: e
# Error processing edge: m
# Error processing edge: o
# Error processing edge: v
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: t
# Error processing edge: h
# Error processing edge: r
# Error processing edge: o
# Error processing edge: u
# Error processing edge: g
# Error processing edge: h
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: i
# Error processing edge: n
# Error processing edge: c
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: s
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: o
# Error processing edge: n
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge:
# Error processing edge: s
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge:
# Error processing edge: t
# Error processing edge: o
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge:
# Error processing edge: s
# Error processing edge: u
# Error processing edge: b
# Error processing edge: m
# Error processing edge: i
# Error processing edge: t
# Error processing edge: t
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: t
# Error processing edge: o
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge:
# Error processing edge: w
# Error processing edge: a
# Error processing edge: s
# Error processing edge:
# Error processing edge: r
# Error processing edge: e
# Error processing edge: m
# Error processing edge: o
# Error processing edge: v
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: b
# Error processing edge: y
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge:
# Error processing edge: r
# Error processing edge: e
# Error processing edge: m
# Error processing edge: o
# Error processing edge: v
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: t
# Error processing edge: h
# Error processing edge: r
# Error processing edge: o
# Error processing edge: u
# Error processing edge: g
# Error processing edge: h
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: u
# Error processing edge: s
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: f
# Error processing edge: o
# Error processing edge: r
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: i
# Error processing edge: n
# Error processing edge: c
# Error processing edge: l
# Error processing edge: u
# Error processing edge: d
# Error processing edge: e
# Error processing edge: s
# Error processing edge:
# Error processing edge: u
# Error processing edge: s
# Error processing edge: e
# Error processing edge:
# Error processing edge: o
# Error processing edge: f
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: p
# Error processing edge: r
# Error processing edge: e
# Error processing edge: p
# Error processing edge: a
# Error processing edge: r
# Error processing edge: a
# Error processing edge: t
# Error processing edge: i
# Error processing edge: o
# Error processing edge: n
# Error processing edge:
# Error processing edge: o
# Error processing edge: f
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: c
# Error processing edge: h
# Error processing edge: a
# Error processing edge: r
# Error processing edge: a
# Error processing edge: c
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: z
# Error processing edge: e
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: p
# Error processing edge: a
# Error processing edge: r
# Error processing edge: t
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: l
# Error processing edge: y
# Error processing edge:
# Error processing edge: r
# Error processing edge: e
# Error processing edge: s
# Error processing edge: t
# Error processing edge: o
# Error processing edge: r
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: o
# Error processing edge: n
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: c
# Error processing edge: e
# Error processing edge: s
# Error processing edge: s
# Error processing edge: ]
# Error processing edge:
# Error processing edge: i
# Error processing edge: n
# Error processing edge: c
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: s
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: [
# Error processing edge: m
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: a
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: t
# Error processing edge: o
# Error processing edge: o
# Error processing edge: l
# Error processing edge: ]
# Error processing edge:
# Error processing edge: c
# Error processing edge: l
# Error processing edge: a
# Error processing edge: s
# Error processing edge: s
# Error processing edge: i
# Error processing edge: f
# Error processing edge: y
# Error processing edge:
# Error processing edge: [
# Error processing edge: l
# Error processing edge: o
# Error processing edge: c
# Error processing edge: a
# Error processing edge: t
# Error processing edge: i
# Error processing edge: o
# Error processing edge: n
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: t
# Error processing edge: o
# Error processing edge: o
# Error processing edge: l
# Error processing edge: ]
# Error processing edge:
# Error processing edge: c
# Error processing edge: h
# Error processing edge: a
# Error processing edge: r
# Error processing edge: a
# Error processing edge: c
# Error processing edge: t
# Error processing edge: e
# Error processing edge: r
# Error processing edge: i
# Error processing edge: z
# Error processing edge: e
# Error processing edge:
# Error processing edge: [
# Error processing edge: l
# Error processing edge: o
# Error processing edge: c
# Error processing edge: a
# Error processing edge: t
# Error processing edge: i
# Error processing edge: o
# Error processing edge: n
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: d
# Error processing edge: a
# Error processing edge: t
# Error processing edge: a
# Error processing edge: b
# Error processing edge: a
# Error processing edge: s
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: h
# Error processing edge: o
# Error processing edge: s
# Error processing edge: t
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: b
# Error processing edge: y
# Error processing edge:
# Error processing edge: [
# Error processing edge: t
# Error processing edge: o
# Error processing edge: o
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: d
# Error processing edge: a
# Error processing edge: t
# Error processing edge: a
# Error processing edge: b
# Error processing edge: a
# Error processing edge: s
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: h
# Error processing edge: o
# Error processing edge: s
# Error processing edge: t
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: o
# Error processing edge: n
# Error processing edge:
# Error processing edge: [
# Error processing edge: t
# Error processing edge: o
# Error processing edge: o
# Error processing edge: l
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge:
# Error processing edge: e
# Error processing edge: n
# Error processing edge: c
# Error processing edge: o
# Error processing edge: d
# Error processing edge: e
# Error processing edge:
# Error processing edge: [
# Error processing edge: e
# Error processing edge: n
# Error processing edge: z
# Error processing edge: y
# Error processing edge: m
# Error processing edge: e
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: t
# Error processing edge: r
# Error processing edge: e
# Error processing edge: a
# Error processing edge: t
# Error processing edge: m
# Error processing edge: e
# Error processing edge: n
# Error processing edge: t
# Error processing edge: ]
# Error processing edge:
# Error processing edge: e
# Error processing edge: n
# Error processing edge: c
# Error processing edge: o
# Error processing edge: d
# Error processing edge: i
# Error processing edge: n
# Error processing edge: g
# Error processing edge:
# Error processing edge: [
# Error processing edge: e
# Error processing edge: n
# Error processing edge: z
# Error processing edge: y
# Error processing edge: m
# Error processing edge: e
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: participating in [process]
# Error processing edge: have significant similarity to [protein]
# Error processing edge: links [protein domain]
# Error processing edge: **[protein domain] prevents interaction**
# Error processing edge: between [protein domain]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: t
# Error processing edge: e
# Error processing edge: c
# Error processing edge: h
# Error processing edge: n
# Error processing edge: i
# Error processing edge: q
# Error processing edge: u
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: i
# Error processing edge: s
# Error processing edge: o
# Error processing edge: l
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: t
# Error processing edge: e
# Error processing edge: c
# Error processing edge: h
# Error processing edge: n
# Error processing edge: i
# Error processing edge: q
# Error processing edge: u
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: i
# Error processing edge: s
# Error processing edge: o
# Error processing edge: l
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge: ]
# Error processing edge:
# Error processing edge: p
# Error processing edge: h
# Error processing edge: o
# Error processing edge: s
# Error processing edge: p
# Error processing edge: h
# Error processing edge: o
# Error processing edge: r
# Error processing edge: y
# Error processing edge: l
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: t
# Error processing edge: h
# Error processing edge: r
# Error processing edge: o
# Error processing edge: u
# Error processing edge: g
# Error processing edge: h
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: a
# Error processing edge: t
# Error processing edge: h
# Error processing edge: w
# Error processing edge: a
# Error processing edge: y
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge: ]
# Error processing edge:
# Error processing edge: i
# Error processing edge: s
# Error processing edge:
# Error processing edge: p
# Error processing edge: h
# Error processing edge: o
# Error processing edge: s
# Error processing edge: p
# Error processing edge: h
# Error processing edge: o
# Error processing edge: r
# Error processing edge: y
# Error processing edge: l
# Error processing edge: a
# Error processing edge: t
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: t
# Error processing edge: h
# Error processing edge: r
# Error processing edge: o
# Error processing edge: u
# Error processing edge: g
# Error processing edge: h
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: a
# Error processing edge: t
# Error processing edge: h
# Error processing edge: w
# Error processing edge: a
# Error processing edge: y
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge:
# Error processing edge: c
# Error processing edge: o
# Error processing edge: m
# Error processing edge: p
# Error processing edge: l
# Error processing edge: e
# Error processing edge: x
# Error processing edge: ]
# Error processing edge:
# Error processing edge: b
# Error processing edge: e
# Error processing edge: l
# Error processing edge: o
# Error processing edge: n
# Error processing edge: g
# Error processing edge:
# Error processing edge: t
# Error processing edge: o
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge:
# Error processing edge: f
# Error processing edge: a
# Error processing edge: m
# Error processing edge: i
# Error processing edge: l
# Error processing edge: y
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge:
# Error processing edge: c
# Error processing edge: o
# Error processing edge: m
# Error processing edge: p
# Error processing edge: l
# Error processing edge: e
# Error processing edge: x
# Error processing edge: ]
# Error processing edge:
# Error processing edge: b
# Error processing edge: e
# Error processing edge: l
# Error processing edge: o
# Error processing edge: n
# Error processing edge: g
# Error processing edge: s
# Error processing edge:
# Error processing edge: t
# Error processing edge: o
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge:
# Error processing edge: f
# Error processing edge: a
# Error processing edge: m
# Error processing edge: i
# Error processing edge: l
# Error processing edge: y
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: share binding partners with [protein]
# Error processing edge: strongest binding partner of [protein]
# Error processing edge: **[protein complex] regulate function**
# Error processing edge: [
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: s
# Error processing edge: h
# Error processing edge: a
# Error processing edge: r
# Error processing edge: e
# Error processing edge: s
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: [
# Error processing edge: p
# Error processing edge: h
# Error processing edge: e
# Error processing edge: n
# Error processing edge: o
# Error processing edge: t
# Error processing edge: y
# Error processing edge: p
# Error processing edge: e
# Error processing edge: ]
# Error processing edge:
# Error processing edge: s
# Error processing edge: h
# Error processing edge: a
# Error processing edge: r
# Error processing edge: e
# Error processing edge: d
# Error processing edge:
# Error processing edge: w
# Error processing edge: i
# Error processing edge: t
# Error processing edge: h
# Error processing edge:
# Error processing edge: [
# Error processing edge: p
# Error processing edge: r
# Error processing edge: o
# Error processing edge: t
# Error processing edge: e
# Error processing edge: i
# Error processing edge: n
# Error processing edge: ]
# Error processing edge: *
# Error processing edge: *
# Error processing edge: ]
# Error processing edge: decrease throughout [subcellular compartment]
# Error processing edge: lack of [protein domain]

# %%
merged_df
# Out:
#            id                                      output_string  \
# 0           0  {"0":"[[\"**[organ] correlated with [metabolit...
# 1           1                                         {"1":"[]"}
# 2           2  {"2":"[[\"**[organ] leads to [metabolite]**\",...
# 3           3  {"3":"[[\"**[organ] involves [metabolite]**\",...
# 4           4  {"4":"[[\"**[organ] related to [metabolite]**\...
# ...       ...                                                ...
# 98555  116971  {"116971":"[[\"**[gene] are classified into [p...
# 98556  116972  {"116972":"[[\"**[gene] differ in [protein dom...
# 98557  116973  {"116973":"[[\"**[gene] evolved to [protein do...
# 98558  116974                                    {"116974":"[]"}
# 98559  116975  {"116975":"[[\"**[gene] divided into [protein ...
#
#                                           ids_in_cluster  \
# 0      [[organ] correlated with [metabolic pathway], ...
# 1      [[organ] mediates [metabolite], [organ] suppor...
# 2      [[metabolite] self-organizes along [organ], [o...
# 3      [[organ] involves [metabolite], [organ] affect...
# 4      [[organ] related to [metabolite], [organ] rela...
# ...                                                  ...
# 98555  [[gene] are classified into [protein domain], ...
# 98556  [[gene] features [protein domain], [gene] diff...
# 98557  [[gene] belonged to [protein domain], [gene] e...
# 98558  [[gene] predict [protein domain], [gene] ident...
# 98559  [[gene] were used to create [protein domain], ...
#
#                                         finetuned_output  \
# 0      {'0': '[["**[organ] correlated with [metabolit...
# 1                                            {'1': '[]'}
# 2      {'2': '[["**[organ] leads to [metabolite]**", ...
# 3      {'3': '[["**[organ] involves [metabolite]**", ...
# 4      {'4': '[["**[organ] related to [metabolite]**"...
# ...                                                  ...
# 98555  {'116971': '[["**[gene] are classified into [p...
# 98556  {'116972': '[["**[gene] differ in [protein dom...
# 98557  {'116973': '[["**[gene] evolved to [protein do...
# 98558                                   {'116974': '[]'}
# 98559  {'116975': '[["**[gene] divided into [protein ...
#
#        finetuned_output_parsed  \
# 0                         True
# 1                         True
# 2                         True
# 3                         True
# 4                         True
# ...                        ...
# 98555                     True
# 98556                     True
# 98557                     True
# 98558                     True
# 98559                     True
#
#                                           finetuned_list  \
# 0      [[**[organ] correlated with [metabolite]**, [o...
# 1                                                     []
# 2      [[**[organ] leads to [metabolite]**, [organ] l...
# 3      [[**[organ] involves [metabolite]**, [organ] i...
# 4      [[**[organ] related to [metabolite]**, [organ]...
# ...                                                  ...
# 98555  [[**[gene] are classified into [protein domain...
# 98556  [[**[gene] differ in [protein domain]**, [gene...
# 98557  [[**[gene] evolved to [protein domain]**, [gen...
# 98558                                                 []
# 98559  [[**[gene] divided into [protein domain]**, [g...
#
#                                           flattened_list  \
# 0      [**[organ] correlated with [metabolite]**, [or...
# 1                                                     []
# 2      [**[organ] leads to [metabolite]**, [organ] le...
# 3      [**[organ] involves [metabolite]**, [organ] in...
# 4      [**[organ] related to [metabolite]**, [organ] ...
# ...                                                  ...
# 98555  [**[gene] are classified into [protein domain]...
# 98556  [**[gene] differ in [protein domain]**, [gene]...
# 98557  [**[gene] evolved to [protein domain]**, [gene...
# 98558                                                 []
# 98559  [**[gene] divided into [protein domain]**, [ge...
#
#        output_matches_input  finetuned_representative_in_list  \
# 0                      True                              True
# 1                      True                              True
# 2                      True                              True
# 3                      True                              True
# 4                      True                              True
# ...                     ...                               ...
# 98555                 False                              True
# 98556                  True                              True
# 98557                  True                              True
# 98558                  True                              True
# 98559                  True                              True
#
#        all_edges_have_same_types
# 0                           True
# 1                           True
# 2                           True
# 3                           True
# 4                           True
# ...                          ...
# 98555                       True
# 98556                       True
# 98557                       True
# 98558                       True
# 98559                       True
#
# [98120 rows x 10 columns]

# %%
rerun_df
# Out:
#            id                                   finetuned_output  \
# 2464     2937                                                 []
# 4656     5527                                                 []
# 5626     6664                                                 []
# 6459     7659                                                 []
# 6832     8102                                                 []
# ...       ...                                                ...
# 97074  115198  {'115198': '[["**[protein] dimerize with [gene...
# 97349  115524  {'115524': '[["**[gene] couples to [protein]**...
# 97967  116274  {'116274': '[["**[gene] inserts [protein compl...
# 98008  116326  {'116326': '[["**[gene] identifies [protein co...
# 98034  116359  {'116359': '[["**[genetic element] loaded into...
#
#                                           ids_in_cluster  \
# 2464   [[phenotype] is the limiting step in the forma...
# 4656   [[gene] consist mainly of [metabolite], [gene]...
# 5626   [[gene] as intermediates in [metabolite], [gen...
# 6459   [[gene] were down-regulated in [metabolite], [...
# 6832   [[enzyme] catalyzes [metabolite], [enzyme] cat...
# ...                                                  ...
# 97074  [[protein] dimerize with [gene], [protein] dis...
# 97349  [[gene] couples to [protein], [gene] are partn...
# 97967  [[gene] inserts [protein complex], [gene] is i...
# 98008  [[gene] identifies [protein complex], [gene] l...
# 98034  [[genetic element] loaded into [protein comple...
#
#        finetuned_output_parsed finetuned_list
# 2464                     False            NaN
# 4656                     False            NaN
# 5626                     False            NaN
# 6459                     False            NaN
# 6832                     False            NaN
# ...                        ...            ...
# 97074                     True           None
# 97349                     True           None
# 97967                     True           None
# 98008                     True           None
# 98034                     True           None
#
# [440 rows x 5 columns]

# %%
merged_df["all_edges_have_same_types"].value_counts()
# Out:
# all_edges_have_same_types
# True     91100
# False     7020
# Name: count, dtype: int64

# %%
wrong_edges_df = merged_df[merged_df["all_edges_have_same_types"] == False]
wrong_edges_df
# Out:
#            id                                      output_string  \
# 119       134  {"134":"[[\"**[organ] are strong sinks of [met...
# 146       163  {"163":"[[\"**[metabolite] fails to accumulate...
# 151       168  {"168":"[[\"**[organism] unable to accumulate ...
# 154       171  {"171":"[[\"**[organ] cannot provide sufficien...
# 186       208  {"208":"[[\"**[metabolite] did not change in [...
# ...       ...                                                ...
# 98461  116850  {"116850":"[[\"**[protein domain] decreased in...
# 98465  116854  {"116854":"[[\"**[protein domain] interact wit...
# 98496  116892  {"116892":"[[\"**[protein domain] characterize...
# 98512  116918  {"116918":"[[\"**[gene] has a [protein domain]...
# 98533  116944  {"116944":"[[\"**[gene] contain [protein domai...
#
#                                           ids_in_cluster  \
# 119    [[organ] are strong sinks of [metabolite], [or...
# 146    [[metabolite] failed to reduce the growth of [...
# 151    [[organism] unable to accumulate [metabolite],...
# 154    [[metabolite] is not sufficient to attract [or...
# 186    [[metabolite] did not change in [organism], [o...
# ...                                                  ...
# 98461  [[protein domain] decreased interaction intens...
# 98465  [[protein domain] interact with [gene], [gene]...
# 98496  [[protein domain] classified into [gene], [pro...
# 98512  [[gene] has five [protein domain], [gene] has ...
# 98533  [[gene] contain [protein domain], [gene] conta...
#
#                                         finetuned_output  \
# 119    {'134': '[["**[organ] are strong sinks of [met...
# 146    {'163': '[["**[metabolite] fails to accumulate...
# 151    {'168': '[["**[organism] unable to accumulate ...
# 154    {'171': '[["**[organ] cannot provide sufficien...
# 186    {'208': '[["**[metabolite] did not change in [...
# ...                                                  ...
# 98461  {'116850': '[["**[protein domain] decreased in...
# 98465  {'116854': '[["**[protein domain] interact wit...
# 98496  {'116892': '[["**[protein domain] characterize...
# 98512  {'116918': '[["**[gene] has a [protein domain]...
# 98533  {'116944': '[["**[gene] contain [protein domai...
#
#        finetuned_output_parsed  \
# 119                       True
# 146                       True
# 151                       True
# 154                       True
# 186                       True
# ...                        ...
# 98461                     True
# 98465                     True
# 98496                     True
# 98512                     True
# 98533                     True
#
#                                           finetuned_list  \
# 119    [[**[organ] are strong sinks of [metabolite]**...
# 146    [[**[metabolite] fails to accumulate in [organ...
# 151    [[**[organism] unable to accumulate [metabolit...
# 154    [[**[organ] cannot provide sufficient [metabol...
# 186    [[**[metabolite] did not change in [organism]*...
# ...                                                  ...
# 98461  [[**[protein domain] decreased interaction int...
# 98465  [[**[protein domain] interact with [gene]**, [...
# 98496  [[**[protein domain] characterizes [gene]**, [...
# 98512  [[**[gene] has a [protein domain]**, [gene] ha...
# 98533  [[**[gene] contain [protein domain]**, [gene] ...
#
#                                           flattened_list  \
# 119    [**[organ] are strong sinks of [metabolite]**,...
# 146    [**[metabolite] fails to accumulate in [organ]...
# 151    [**[organism] unable to accumulate [metabolite...
# 154    [**[organ] cannot provide sufficient [metaboli...
# 186    [**[metabolite] did not change in [organism]**...
# ...                                                  ...
# 98461  [**[protein domain] decreased interaction inte...
# 98465  [**[protein domain] interact with [gene]**, [g...
# 98496  [**[protein domain] characterizes [gene]**, [p...
# 98512  [**[gene] has a [protein domain]**, [gene] has...
# 98533  [**[gene] contain [protein domain]**, [gene] c...
#
#        output_matches_input  finetuned_representative_in_list  \
# 119                    True                              True
# 146                    True                              True
# 151                    True                              True
# 154                    True                              True
# 186                    True                              True
# ...                     ...                               ...
# 98461                  True                              True
# 98465                  True                              True
# 98496                  True                              True
# 98512                  True                              True
# 98533                  True                              True
#
#        all_edges_have_same_types
# 119                        False
# 146                        False
# 151                        False
# 154                        False
# 186                        False
# ...                          ...
# 98461                      False
# 98465                      False
# 98496                      False
# 98512                      False
# 98533                      False
#
# [7020 rows x 10 columns]

# %%
rerun_df
# Out:
#            id                                      output_string  \
# 2464     2937  {"2937":"[[\"**[metabolite] is limiting and re...
# 4656     5527  {"5527":"[[\"**[gene] consist of [metabolite]*...
# 5626     6664  {"6664":"[[\"**[gene] encode enzyme activities...
# 6459     7659  {"7659":"[[\"**[gene] were downregulated by [m...
# 6832     8102  {"8102":"[[\"**[enzyme] catalyzes [metabolite]...
# ...       ...                                                ...
# 97074  115198  {"115198":"[[\"**[protein] dimerize with [gene...
# 97349  115524  {"115524":"[[\"**[gene] couples to [protein]**...
# 97967  116274  {"116274":"[[\"**[gene] inserts [protein compl...
# 98008  116326  {"116326":"[[\"**[gene] identifies [protein co...
# 98034  116359  {"116359":"[[\"**[genetic element] loaded into...
#
#                                           ids_in_cluster  \
# 2464   [[phenotype] is the limiting step in the forma...
# 4656   [[gene] consist mainly of [metabolite], [gene]...
# 5626   [[gene] as intermediates in [metabolite], [gen...
# 6459   [[gene] were down-regulated in [metabolite], [...
# 6832   [[enzyme] catalyzes [metabolite], [enzyme] cat...
# ...                                                  ...
# 97074  [[protein] dimerize with [gene], [protein] dis...
# 97349  [[gene] couples to [protein], [gene] are partn...
# 97967  [[gene] inserts [protein complex], [gene] is i...
# 98008  [[gene] identifies [protein complex], [gene] l...
# 98034  [[genetic element] loaded into [protein comple...
#
#                                         finetuned_output  \
# 2464                                                  []
# 4656                                                  []
# 5626                                                  []
# 6459                                                  []
# 6832                                                  []
# ...                                                  ...
# 97074  {'115198': '[["**[protein] dimerize with [gene...
# 97349  {'115524': '[["**[gene] couples to [protein]**...
# 97967  {'116274': '[["**[gene] inserts [protein compl...
# 98008  {'116326': '[["**[gene] identifies [protein co...
# 98034  {'116359': '[["**[genetic element] loaded into...
#
#        finetuned_output_parsed finetuned_list
# 2464                     False            NaN
# 4656                     False            NaN
# 5626                     False            NaN
# 6459                     False            NaN
# 6832                     False            NaN
# ...                        ...            ...
# 97074                     True           None
# 97349                     True           None
# 97967                     True           None
# 98008                     True           None
# 98034                     True           None
#
# [440 rows x 6 columns]

# %%
merged_df
# Out:
#            id                                      output_string  \
# 0           0  {"0":"[[\"**[organ] correlated with [metabolit...
# 1           1                                         {"1":"[]"}
# 2           2  {"2":"[[\"**[organ] leads to [metabolite]**\",...
# 3           3  {"3":"[[\"**[organ] involves [metabolite]**\",...
# 4           4  {"4":"[[\"**[organ] related to [metabolite]**\...
# ...       ...                                                ...
# 98555  116971  {"116971":"[[\"**[gene] are classified into [p...
# 98556  116972  {"116972":"[[\"**[gene] differ in [protein dom...
# 98557  116973  {"116973":"[[\"**[gene] evolved to [protein do...
# 98558  116974                                    {"116974":"[]"}
# 98559  116975  {"116975":"[[\"**[gene] divided into [protein ...
#
#                                           ids_in_cluster  \
# 0      [[organ] correlated with [metabolic pathway], ...
# 1      [[organ] mediates [metabolite], [organ] suppor...
# 2      [[metabolite] self-organizes along [organ], [o...
# 3      [[organ] involves [metabolite], [organ] affect...
# 4      [[organ] related to [metabolite], [organ] rela...
# ...                                                  ...
# 98555  [[gene] are classified into [protein domain], ...
# 98556  [[gene] features [protein domain], [gene] diff...
# 98557  [[gene] belonged to [protein domain], [gene] e...
# 98558  [[gene] predict [protein domain], [gene] ident...
# 98559  [[gene] were used to create [protein domain], ...
#
#                                         finetuned_output  \
# 0      {'0': '[["**[organ] correlated with [metabolit...
# 1                                            {'1': '[]'}
# 2      {'2': '[["**[organ] leads to [metabolite]**", ...
# 3      {'3': '[["**[organ] involves [metabolite]**", ...
# 4      {'4': '[["**[organ] related to [metabolite]**"...
# ...                                                  ...
# 98555  {'116971': '[["**[gene] are classified into [p...
# 98556  {'116972': '[["**[gene] differ in [protein dom...
# 98557  {'116973': '[["**[gene] evolved to [protein do...
# 98558                                   {'116974': '[]'}
# 98559  {'116975': '[["**[gene] divided into [protein ...
#
#        finetuned_output_parsed  \
# 0                         True
# 1                         True
# 2                         True
# 3                         True
# 4                         True
# ...                        ...
# 98555                     True
# 98556                     True
# 98557                     True
# 98558                     True
# 98559                     True
#
#                                           finetuned_list  \
# 0      [[**[organ] correlated with [metabolite]**, [o...
# 1                                                     []
# 2      [[**[organ] leads to [metabolite]**, [organ] l...
# 3      [[**[organ] involves [metabolite]**, [organ] i...
# 4      [[**[organ] related to [metabolite]**, [organ]...
# ...                                                  ...
# 98555  [[**[gene] are classified into [protein domain...
# 98556  [[**[gene] differ in [protein domain]**, [gene...
# 98557  [[**[gene] evolved to [protein domain]**, [gen...
# 98558                                                 []
# 98559  [[**[gene] divided into [protein domain]**, [g...
#
#                                           flattened_list  \
# 0      [**[organ] correlated with [metabolite]**, [or...
# 1                                                     []
# 2      [**[organ] leads to [metabolite]**, [organ] le...
# 3      [**[organ] involves [metabolite]**, [organ] in...
# 4      [**[organ] related to [metabolite]**, [organ] ...
# ...                                                  ...
# 98555  [**[gene] are classified into [protein domain]...
# 98556  [**[gene] differ in [protein domain]**, [gene]...
# 98557  [**[gene] evolved to [protein domain]**, [gene...
# 98558                                                 []
# 98559  [**[gene] divided into [protein domain]**, [ge...
#
#        output_matches_input  finetuned_representative_in_list  \
# 0                      True                              True
# 1                      True                              True
# 2                      True                              True
# 3                      True                              True
# 4                      True                              True
# ...                     ...                               ...
# 98555                 False                              True
# 98556                  True                              True
# 98557                  True                              True
# 98558                  True                              True
# 98559                  True                              True
#
#        all_edges_have_same_types
# 0                           True
# 1                           True
# 2                           True
# 3                           True
# 4                           True
# ...                          ...
# 98555                       True
# 98556                       True
# 98557                       True
# 98558                       True
# 98559                       True
#
# [98120 rows x 10 columns]

# %%
rerun_df = pd.concat([merged_df[merged_df["finetuned_representative_in_list"] == False], rerun_df])
merged_df = merged_df[merged_df["finetuned_representative_in_list"] == True]
merged_df.loc[:, ["id", "output_string", "ids_in_cluster"]].to_parquet('/home/mads/connectome/data/predictions/v8_merged_20250407_141507.parquet')

# %%
rerun_df
# Out:
#            id                                   finetuned_output  \
# 4200     4974  {'4974': '[["**[metabolite] hastens [phenotype...
# 10442   12403  {'12403': '[["**[protein] impairs [metabolite]...
# 12118   14380  {'14380': '[["**[metabolite] allocated to [tis...
# 12347   14652  {'14652': '[["**[metabolite] blocks [subcellul...
# 12462   14788  {'14788': '[["**[metabolite] identifies [subce...
# ...       ...                                                ...
# 97074  115198  {'115198': '[["**[protein] dimerize with [gene...
# 97349  115524  {'115524': '[["**[gene] couples to [protein]**...
# 97967  116274  {'116274': '[["**[gene] inserts [protein compl...
# 98008  116326  {'116326': '[["**[gene] identifies [protein co...
# 98034  116359  {'116359': '[["**[genetic element] loaded into...
#
#                                           ids_in_cluster  \
# 4200   [[metabolite] hastens [phenotype], [metabolite...
# 10442  [[protein complex] impairs production of [meta...
# 12118  [[metabolite] allocated to [tissue], [metaboli...
# 12347  [[metabolite] blocks [subcellular compartment]...
# 12462  [[metabolite] identifies [subcellular compartm...
# ...                                                  ...
# 97074  [[protein] dimerize with [gene], [protein] dis...
# 97349  [[gene] couples to [protein], [gene] are partn...
# 97967  [[gene] inserts [protein complex], [gene] is i...
# 98008  [[gene] identifies [protein complex], [gene] l...
# 98034  [[genetic element] loaded into [protein comple...
#
#        finetuned_output_parsed  \
# 4200                      True
# 10442                     True
# 12118                     True
# 12347                     True
# 12462                     True
# ...                        ...
# 97074                     True
# 97349                     True
# 97967                     True
# 98008                     True
# 98034                     True
#
#                                           finetuned_list  \
# 4200   [[**[metabolite] hastens [phenotype]**, [metab...
# 10442  [[**[protein] impairs [metabolite]**, [protein...
# 12118  [[**[metabolite] allocated to [tissue]**, [met...
# 12347  [[**[metabolite] blocks [subcellular compartme...
# 12462  [[**[metabolite] identifies [subcellular compa...
# ...                                                  ...
# 97074                                                NaN
# 97349                                                NaN
# 97967                                                NaN
# 98008                                                NaN
# 98034                                                NaN
#
#                                           flattened_list output_matches_input  \
# 4200   [**[metabolite] hastens [phenotype]**, [metabo...                False
# 10442  [**[protein] impairs [metabolite]**, [protein]...                False
# 12118  [**[metabolite] allocated to [tissue]**, [meta...                False
# 12347  [**[metabolite] blocks [subcellular compartmen...                False
# 12462  [**[metabolite] identifies [subcellular compar...                False
# ...                                                  ...                  ...
# 97074                                                NaN                  NaN
# 97349                                                NaN                  NaN
# 97967                                                NaN                  NaN
# 98008                                                NaN                  NaN
# 98034                                                NaN                  NaN
#
#       finetuned_representative_in_list all_edges_have_same_types
# 4200                             False                      True
# 10442                            False                      True
# 12118                            False                      True
# 12347                            False                      True
# 12462                            False                      True
# ...                                ...                       ...
# 97074                              NaN                       NaN
# 97349                              NaN                       NaN
# 97967                              NaN                       NaN
# 98008                              NaN                       NaN
# 98034                              NaN                       NaN
#
# [459 rows x 9 columns]

# %%
merged_df
# Out:
#            id                                   finetuned_output  \
# 0           0  {'0': '[["**[organ] correlated with [metabolit...
# 1           1                                        {'1': '[]'}
# 2           2  {'2': '[["**[organ] leads to [metabolite]**", ...
# 3           3  {'3': '[["**[organ] involves [metabolite]**", ...
# 4           4  {'4': '[["**[organ] related to [metabolite]**"...
# ...       ...                                                ...
# 98555  116971  {'116971': '[["**[gene] are classified into [p...
# 98556  116972  {'116972': '[["**[gene] differ in [protein dom...
# 98557  116973  {'116973': '[["**[gene] evolved to [protein do...
# 98558  116974                                   {'116974': '[]'}
# 98559  116975  {'116975': '[["**[gene] divided into [protein ...
#
#                                           ids_in_cluster  \
# 0      [[organ] correlated with [metabolic pathway], ...
# 1      [[organ] mediates [metabolite], [organ] suppor...
# 2      [[metabolite] self-organizes along [organ], [o...
# 3      [[organ] involves [metabolite], [organ] affect...
# 4      [[organ] related to [metabolite], [organ] rela...
# ...                                                  ...
# 98555  [[gene] are classified into [protein domain], ...
# 98556  [[gene] features [protein domain], [gene] diff...
# 98557  [[gene] belonged to [protein domain], [gene] e...
# 98558  [[gene] predict [protein domain], [gene] ident...
# 98559  [[gene] were used to create [protein domain], ...
#
#        finetuned_output_parsed  \
# 0                         True
# 1                         True
# 2                         True
# 3                         True
# 4                         True
# ...                        ...
# 98555                     True
# 98556                     True
# 98557                     True
# 98558                     True
# 98559                     True
#
#                                           finetuned_list  \
# 0      [[**[organ] correlated with [metabolite]**, [o...
# 1                                                     []
# 2      [[**[organ] leads to [metabolite]**, [organ] l...
# 3      [[**[organ] involves [metabolite]**, [organ] i...
# 4      [[**[organ] related to [metabolite]**, [organ]...
# ...                                                  ...
# 98555  [[**[gene] are classified into [protein domain...
# 98556  [[**[gene] differ in [protein domain]**, [gene...
# 98557  [[**[gene] evolved to [protein domain]**, [gen...
# 98558                                                 []
# 98559  [[**[gene] divided into [protein domain]**, [g...
#
#                                           flattened_list  \
# 0      [**[organ] correlated with [metabolite]**, [or...
# 1                                                     []
# 2      [**[organ] leads to [metabolite]**, [organ] le...
# 3      [**[organ] involves [metabolite]**, [organ] in...
# 4      [**[organ] related to [metabolite]**, [organ] ...
# ...                                                  ...
# 98555  [**[gene] are classified into [protein domain]...
# 98556  [**[gene] differ in [protein domain]**, [gene]...
# 98557  [**[gene] evolved to [protein domain]**, [gene...
# 98558                                                 []
# 98559  [**[gene] divided into [protein domain]**, [ge...
#
#        output_matches_input  finetuned_representative_in_list  \
# 0                      True                              True
# 1                      True                              True
# 2                      True                              True
# 3                      True                              True
# 4                      True                              True
# ...                     ...                               ...
# 98555                 False                              True
# 98556                  True                              True
# 98557                  True                              True
# 98558                  True                              True
# 98559                  True                              True
#
#        all_edges_have_same_types
# 0                           True
# 1                           True
# 2                           True
# 3                           True
# 4                           True
# ...                          ...
# 98555                       True
# 98556                       True
# 98557                       True
# 98558                       True
# 98559                       True
#
# [98101 rows x 9 columns]

# %%
def extract_edge_mapping(row):
    """Performed on dataframe with columns:
    - finetuned_list: list of lists of edges
    - ids_in_cluster: list of edges
    """
    edge_mapping = {}

    
    
    #check that the finetuned_list is flattened
    for item in row["finetuned_list"]:
        # Skip if item is not properly formatted
        if not item:
            continue
            
        # Find representative edge (the one containing **)
        representative = None
        for edge in item:
            if isinstance(edge, list):
                
                print(edge)
                print(item)
                print(row["finetuned_list"])
                print("next")
                continue
            if "**" in edge:
                representative = edge.strip("*: ")
                break
                
        if not representative:
            continue
            
        # Map all edges in the group to the representative
        for edge in item:
            if isinstance(edge, list):
                continue
            edge_clean = edge.strip("*: ")
            edge_mapping[edge_clean] = representative


    return edge_mapping

merged_df["edge_mapping"] = merged_df.apply(extract_edge_mapping, axis=1)
# Out:
# /tmp/ipykernel_75537/558148382.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df["edge_mapping"] = merged_df.apply(extract_edge_mapping, axis=1)

# %%
#combine the edge mapping into a single dictionary
edge_mapping = {}
for index, row in merged_df.iterrows():
    edge_mapping.update(row["edge_mapping"])


len(edge_mapping)
# Out:
# 515207

# %%
kg_df = pd.read_parquet('/home/mads/connectome/data/KG/nodes_remapped_kg.parquet')
initial_length = len(kg_df)

# %%
def map_edge_to_kg(row):
    source_type = row["mapped_source_type"]
    target_type = row["mapped_target_type"]
    edge = row["interaction"]
    
    input_edge = f"[{source_type}] {edge.strip("*: ")} [{target_type}]"

    try:
        mapped_edge_type = edge_mapping[input_edge]
    except:
        mapped_edge_type = input_edge

    try:
        map_source_type = mapped_edge_type.split("]")[0][1:].strip(" ")
        map_target_type = mapped_edge_type.split("[")[2][:-1].strip(" ")
        map_edge = mapped_edge_type.split("]")[1].split("[")[0].strip(" ")
    except IndexError:
        return edge
    
    
    if map_source_type.strip(" ") == source_type and map_target_type.strip(" ") == target_type:
        return map_edge
    else:
        return edge
    
    


kg_df["mapped_edge"] = kg_df.apply(map_edge_to_kg, axis=1)

# %%
(kg_df["mapped_edge"] != kg_df["interaction"]).value_counts()
# Out:
# False    3475279
# True     1343960
# Name: count, dtype: int64

# %%
print(kg_df["interaction"].nunique())
print(kg_df["mapped_edge"].nunique())
print(kg_df["interaction"].nunique() - kg_df["mapped_edge"].nunique())
# Out:
# 461199
# 352138
# 109061

# %%
final_length = len(kg_df)
assert initial_length == final_length

# %%
kg_df.to_parquet("/home/mads/connectome/data/KG/20250331_nodes_and_edges_remapped_kg.parquet")

# %%
kg_df
# Out:
#                                                     source source type  \
# 0                                    SUCROSE TRANSPORTER 5        gene
# 1                                    SUCROSE TRANSPORTER 5        gene
# 2                                          SUC5 protein(s)        gene
# 3                                                     SUC5        gene
# 4                                                     SUC5        gene
# ...                                                    ...         ...
# 4819234                            Transgenic poplar lines      mutant
# 4819235                            Transgenic poplar lines      mutant
# 4819236                                             RT-PCR   treatment
# 4819237  variation in relative abundance of STO1 transc...        gene
# 4819238                                        Transgenics      mutant
#
#                                    interaction  \
# 0                                     supplies
# 1                                       affect
# 2                                   represents
# 3                                   transports
# 4                                 localizes to
# ...                                        ...
# 4819234    had greater levels of resistance to
# 4819235  had greater levels of resistance than
# 4819236                 indicated variation in
# 4819237                         coincided with
# 4819238                       were compared to
#
#                                         target              target type  gene  \
# 0                          A. thaliana embryos                 organism  BIO2
# 1                 Triacylglycerol accumulation                phenotype  BIO2
# 2                         sucrose/H+ symporter                  protein  BIO2
# 3                                       biotin               metabolite  BIO2
# 4                              plasma membrane  subcellular compartment  BIO2
# ...                                        ...                      ...   ...
# 4819234                                   NaCl               metabolite  STO1
# 4819235                                     wt                 organism  STO1
# 4819236  relative abundance of STO1 transcript                     gene  STO1
# 4819237                      tolerance to salt                phenotype  STO1
# 4819238        controls undergoing salt stress                 organism  STO1
#
#          pubmedID           p_source                    species  \
# 0        23031218  23031218_abstract       Arabidopsis thaliana
# 1        23031218  23031218_abstract       Arabidopsis thaliana
# 2        23031218  23031218_abstract       Arabidopsis thaliana
# 3        23031218  23031218_abstract       Arabidopsis thaliana
# 4        23031218  23031218_abstract       Arabidopsis thaliana
# ...           ...                ...                        ...
# 4819234  24929937  24929937_abstract  Populus tremula × P. alba
# 4819235  24929937  24929937_abstract  Populus tremula × P. alba
# 4819236  24929937  24929937_abstract  Populus tremula × P. alba
# 4819237  24929937  24929937_abstract  Populus tremula × P. alba
# 4819238  24929937  24929937_abstract  Populus tremula × P. alba
#
#                                                      basis  \
# 0        Uptake measurements of radiolabelled biotin in...
# 1                     TAG content analysis in suc5 mutants
# 2                      Functional analysis of SUC5 protein
# 3        Uptake measurements of radiolabelled biotin in...
# 4         Subcellular localization studies of SUC5 protein
# ...                                                    ...
# 4819234  Greenhouse trials showing greater resistance t...
# 4819235  Greenhouse trials showing greater resistance t...
# 4819236  RT-PCR analysis of STO1 transcript levels in t...
# 4819237  RT-PCR analysis of STO1 transcript levels in t...
# 4819238  Greenhouse trials comparing transgenic poplar ...
#
#                                source_extracted_definition  \
# 0        A gene encoding a transporter that facilitates...
# 1        A gene encoding a transporter that facilitates...
# 2        Proteins encoded by the SUC5 gene, responsible...
# 3        A gene encoding a sucrose transporter that als...
# 4        A gene encoding a sucrose transporter that als...
# ...                                                    ...
# 4819234  Poplar plants genetically modified to express ...
# 4819235  Poplar plants genetically modified to express ...
# 4819236  Reverse transcription polymerase chain reactio...
# 4819237  Differences in the expression levels of the ST...
# 4819238  Organisms that have been genetically modified ...
#
#         source_generated_definition  \
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# ...                             ...
# 4819234                        None
# 4819235                        None
# 4819236                        None
# 4819237                        None
# 4819238                        None
#
#                                target_extracted_definition  \
# 0        Embryos from the plant species Arabidopsis tha...
# 1        The buildup of triacylglycerols in plant tissu...
# 2        A protein that facilitates the co-transport of...
# 3        A water-soluble vitamin (Vitamin B7) essential...
# 4        The biological membrane that separates the int...
# ...                                                    ...
# 4819234  Sodium chloride, commonly used to induce salt ...
# 4819235  Wild-type, the standard or non-modified versio...
# 4819236  The level of STO1 gene expression measured in ...
# 4819237  The ability of plants to survive and grow in s...
# 4819238  Wild-type plants subjected to salt stress for ...
#
#         target_generated_definition source type disamb  \
# 0                              None               gene
# 1                              None               gene
# 2                              None               gene
# 3                              None               gene
# 4                              None               gene
# ...                             ...                ...
# 4819234                        None             mutant
# 4819235                        None             mutant
# 4819236                        None          treatment
# 4819237                        None               gene
# 4819238                        None             mutant
#
#               target type disamb  \
# 0                       organism
# 1                      phenotype
# 2                        protein
# 3                     metabolite
# 4        subcellular compartment
# ...                          ...
# 4819234               metabolite
# 4819235                 organism
# 4819236                     gene
# 4819237                phenotype
# 4819238                 organism
#
#                                              mapped_source  \
# 0                                    SUCROSE TRANSPORTER 5
# 1                                    SUCROSE TRANSPORTER 5
# 2                                             SUC5 gene(s)
# 3                                                     SUC5
# 4                                                     SUC5
# ...                                                    ...
# 4819234                            Transgenic poplar lines
# 4819235                            Transgenic poplar lines
# 4819236                                             RT-PCR
# 4819237  variation in relative abundance of STO1 transc...
# 4819238                                        Transgenics
#
#                                  mapped_target mapped_source_type  \
# 0                           A. thaliana embryo               gene
# 1                 Triacylglycerol accumulation               gene
# 2                         sucrose/H+ symporter               gene
# 3                                       biotin               gene
# 4                               plasmamembrane               gene
# ...                                        ...                ...
# 4819234                          NaCl solution             mutant
# 4819235                          WT (wildtype)             mutant
# 4819236  relative abundance of STO1 transcript          treatment
# 4819237                      tolerance to salt               gene
# 4819238        controls undergoing salt stress             mutant
#
#               mapped_target_type              mapped_edge
# 0                       organism                 supplies
# 1                      phenotype                   affect
# 2                        protein               represents
# 3                     metabolite                transport
# 4        subcellular compartment             localizes to
# ...                          ...                      ...
# 4819234               metabolite        more resistant to
# 4819235                 organism  was more resistant than
# 4819236                     gene   indicated variation in
# 4819237                phenotype           coincided with
# 4819238                 organism        was compared with
#
# [4819239 rows x 21 columns]

# %%
# remove duplicates of mapped_edge, mapped target type and mapped source type
kg_removed_duplicates_df = kg_df.drop_duplicates(subset=["mapped_target_type", "mapped_source_type", "mapped_source", "mapped_target", "mapped_edge"])

# %%
kg_removed_duplicates_df
# Out:
#                                                     source source type  \
# 0                                    SUCROSE TRANSPORTER 5        gene
# 1                                    SUCROSE TRANSPORTER 5        gene
# 2                                          SUC5 protein(s)        gene
# 3                                                     SUC5        gene
# 4                                                     SUC5        gene
# ...                                                    ...         ...
# 4819234                            Transgenic poplar lines      mutant
# 4819235                            Transgenic poplar lines      mutant
# 4819236                                             RT-PCR   treatment
# 4819237  variation in relative abundance of STO1 transc...        gene
# 4819238                                        Transgenics      mutant
#
#                                    interaction  \
# 0                                     supplies
# 1                                       affect
# 2                                   represents
# 3                                   transports
# 4                                 localizes to
# ...                                        ...
# 4819234    had greater levels of resistance to
# 4819235  had greater levels of resistance than
# 4819236                 indicated variation in
# 4819237                         coincided with
# 4819238                       were compared to
#
#                                         target              target type  gene  \
# 0                          A. thaliana embryos                 organism  BIO2
# 1                 Triacylglycerol accumulation                phenotype  BIO2
# 2                         sucrose/H+ symporter                  protein  BIO2
# 3                                       biotin               metabolite  BIO2
# 4                              plasma membrane  subcellular compartment  BIO2
# ...                                        ...                      ...   ...
# 4819234                                   NaCl               metabolite  STO1
# 4819235                                     wt                 organism  STO1
# 4819236  relative abundance of STO1 transcript                     gene  STO1
# 4819237                      tolerance to salt                phenotype  STO1
# 4819238        controls undergoing salt stress                 organism  STO1
#
#          pubmedID           p_source                    species  \
# 0        23031218  23031218_abstract       Arabidopsis thaliana
# 1        23031218  23031218_abstract       Arabidopsis thaliana
# 2        23031218  23031218_abstract       Arabidopsis thaliana
# 3        23031218  23031218_abstract       Arabidopsis thaliana
# 4        23031218  23031218_abstract       Arabidopsis thaliana
# ...           ...                ...                        ...
# 4819234  24929937  24929937_abstract  Populus tremula × P. alba
# 4819235  24929937  24929937_abstract  Populus tremula × P. alba
# 4819236  24929937  24929937_abstract  Populus tremula × P. alba
# 4819237  24929937  24929937_abstract  Populus tremula × P. alba
# 4819238  24929937  24929937_abstract  Populus tremula × P. alba
#
#                                                      basis  \
# 0        Uptake measurements of radiolabelled biotin in...
# 1                     TAG content analysis in suc5 mutants
# 2                      Functional analysis of SUC5 protein
# 3        Uptake measurements of radiolabelled biotin in...
# 4         Subcellular localization studies of SUC5 protein
# ...                                                    ...
# 4819234  Greenhouse trials showing greater resistance t...
# 4819235  Greenhouse trials showing greater resistance t...
# 4819236  RT-PCR analysis of STO1 transcript levels in t...
# 4819237  RT-PCR analysis of STO1 transcript levels in t...
# 4819238  Greenhouse trials comparing transgenic poplar ...
#
#                                source_extracted_definition  \
# 0        A gene encoding a transporter that facilitates...
# 1        A gene encoding a transporter that facilitates...
# 2        Proteins encoded by the SUC5 gene, responsible...
# 3        A gene encoding a sucrose transporter that als...
# 4        A gene encoding a sucrose transporter that als...
# ...                                                    ...
# 4819234  Poplar plants genetically modified to express ...
# 4819235  Poplar plants genetically modified to express ...
# 4819236  Reverse transcription polymerase chain reactio...
# 4819237  Differences in the expression levels of the ST...
# 4819238  Organisms that have been genetically modified ...
#
#         source_generated_definition  \
# 0                              None
# 1                              None
# 2                              None
# 3                              None
# 4                              None
# ...                             ...
# 4819234                        None
# 4819235                        None
# 4819236                        None
# 4819237                        None
# 4819238                        None
#
#                                target_extracted_definition  \
# 0        Embryos from the plant species Arabidopsis tha...
# 1        The buildup of triacylglycerols in plant tissu...
# 2        A protein that facilitates the co-transport of...
# 3        A water-soluble vitamin (Vitamin B7) essential...
# 4        The biological membrane that separates the int...
# ...                                                    ...
# 4819234  Sodium chloride, commonly used to induce salt ...
# 4819235  Wild-type, the standard or non-modified versio...
# 4819236  The level of STO1 gene expression measured in ...
# 4819237  The ability of plants to survive and grow in s...
# 4819238  Wild-type plants subjected to salt stress for ...
#
#         target_generated_definition source type disamb  \
# 0                              None               gene
# 1                              None               gene
# 2                              None               gene
# 3                              None               gene
# 4                              None               gene
# ...                             ...                ...
# 4819234                        None             mutant
# 4819235                        None             mutant
# 4819236                        None          treatment
# 4819237                        None               gene
# 4819238                        None             mutant
#
#               target type disamb  \
# 0                       organism
# 1                      phenotype
# 2                        protein
# 3                     metabolite
# 4        subcellular compartment
# ...                          ...
# 4819234               metabolite
# 4819235                 organism
# 4819236                     gene
# 4819237                phenotype
# 4819238                 organism
#
#                                              mapped_source  \
# 0                                    SUCROSE TRANSPORTER 5
# 1                                    SUCROSE TRANSPORTER 5
# 2                                             SUC5 gene(s)
# 3                                                     SUC5
# 4                                                     SUC5
# ...                                                    ...
# 4819234                            Transgenic poplar lines
# 4819235                            Transgenic poplar lines
# 4819236                                             RT-PCR
# 4819237  variation in relative abundance of STO1 transc...
# 4819238                                        Transgenics
#
#                                  mapped_target mapped_source_type  \
# 0                           A. thaliana embryo               gene
# 1                 Triacylglycerol accumulation               gene
# 2                         sucrose/H+ symporter               gene
# 3                                       biotin               gene
# 4                               plasmamembrane               gene
# ...                                        ...                ...
# 4819234                          NaCl solution             mutant
# 4819235                          WT (wildtype)             mutant
# 4819236  relative abundance of STO1 transcript          treatment
# 4819237                      tolerance to salt               gene
# 4819238        controls undergoing salt stress             mutant
#
#               mapped_target_type              mapped_edge
# 0                       organism                 supplies
# 1                      phenotype                   affect
# 2                        protein               represents
# 3                     metabolite                transport
# 4        subcellular compartment             localizes to
# ...                          ...                      ...
# 4819234               metabolite        more resistant to
# 4819235                 organism  was more resistant than
# 4819236                     gene   indicated variation in
# 4819237                phenotype           coincided with
# 4819238                 organism        was compared with
#
# [4732128 rows x 21 columns]
