# %% [markdown]
# ## Generate dataset

# %%
#This is a script that loads a pandas dataframe from csv, converts the string formatted as a list into a list of lists. The list of lists is then flattened into a single list.

import pandas as pd
import random
import json
df = pd.read_csv('./gpt_final_outs/o3mini_maxclust_80_subset_random_1000_nocutoff.csv', index_col=None)

#rename the column "Entity Name" to "Entity" and "Group Items" to "output"
df = df.rename(columns={"Group Items": "Output"})

# Convert the string formatted as a list into a list of lists
df['Output'] = df['Output'].apply(lambda x: eval(x))

# Flatten the list of lists into a single list
df['Input'] = df['Output'].apply(lambda x: [item.strip("*") for sublist in x for item in sublist])

#randomize the order of the single list
df['Input'] = df['Input'].apply(lambda x: random.sample(x, len(x)))
#df = df[df['Input'].apply(len) < 30]
# make a new column, where internal lists of length 1 are removed 
df['Output>1'] = df['Output'].apply(lambda x: [item for item in x if len(item) > 1])
#create a flag column by name one_item. For each row in Output column, If length of the list in output column is less than 2, put True otherwise False.
df['one_item'] = df['Output>1'].apply(lambda x: True if len(x) == 0 else False)

#zip the Group_Items_no_singles with the Entity Name 
df["Output"] = df.apply(lambda row: {row["Entity Name"]: row['Output']}, axis=1)
df["Input"] = df.apply(lambda row: {row["Entity Name"]: row['Input']}, axis=1)
df['Output>1'] = df.apply(lambda row: {row["Entity Name"]: row['Output>1']}, axis=1)





#convert the columns to json strings
df["Output"] = df["Output"].apply(lambda x: json.dumps(x) if isinstance(x, dict) else x)
df["Input"] = df["Input"].apply(lambda x: json.dumps(x) if isinstance(x, dict) else x)
df["Output>1"] = df["Output>1"].apply(lambda x: json.dumps(x) if isinstance(x, dict) else x)

#Change order of columns to have input, then output, then output>1, then entity name
df = df[['Entity Name', 'Input', 'Output', 'Output>1', 'one_item']]

#filter by Output>1 length of the list > 1
#use column Output, but use only the ones where it clusteres multiple items together

# %%
df
#note i don't really use Outputs>1 in this workflow.
# Out:
#      Entity Name                                              Input  \
# 0          58963  {"58963": ["Gardea-Torresdey et al. [researche...
# 1          22775  {"22775": ["physiological transport of macro-m...
# 2          22996  {"22996": ["stomatal conductance analyses [phe...
# 3         100116  {"100116": ["modern clade [gene]", "modern cla...
# 4         133255  {"133255": ["Plastidic LPPs [gene]", "PLSP2B [...
# ..           ...                                                ...
# 995        31615  {"31615": ["auxin-regulated endocytosis [proce...
# 996       157227  {"157227": ["SlSAUR1-like [gene]", "ZmSAUR1 [g...
# 997       131559  {"131559": ["BtuC gene(s) [gene]", "BtuN gene(...
# 998        99091  {"99091": ["O. fragrans 'Liuyejingui' (OFL) [o...
# 999        65306  {"65306": ["CO/NF-YB/NF-YC trimer complex [pro...
#
#                                                 Output  \
# 0    {"58963": [["Gardea-Torresdey et al. [research...
# 1    {"22775": [["substance that could be transloca...
# 2    {"22996": [["**transpiration and stomatal cond...
# 3    {"100116": [["Clade M [clade]"], ["Clade SL [c...
# 4    {"133255": [["**PLSP2A [gene]**", "PLSP2A gene...
# ..                                                 ...
# 995  {"31615": [["auxin-mediated modulation of the ...
# 996  {"157227": [["GmSAUR [gene]"], ["StSAUR [gene]...
# 997  {"131559": [["BtuB gene(s) [gene]"], ["BtuC ge...
# 998  {"99091": [["Genome sequencing of O. fragrans ...
# 999  {"65306": [["**CO/NF-Y complex [protein comple...
#
#                                               Output>1  one_item
# 0                                        {"58963": []}      True
# 1    {"22775": [["**transportation [phenotype]**", ...     False
# 2    {"22996": [["**transpiration and stomatal cond...     False
# 3                                       {"100116": []}      True
# 4    {"133255": [["**PLSP2A [gene]**", "PLSP2A gene...     False
# ..                                                 ...       ...
# 995  {"31615": [["auxin-dependent inhibition of end...     False
# 996  {"157227": [["ZmSAUR1 (Zea mays SAURs) [gene]"...     False
# 997                                     {"131559": []}      True
# 998  {"99091": [["**O. fragrans 'Liuyejingui' (OFL)...     False
# 999  {"65306": [["**CO/NF-Y complex [protein comple...     False
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Prompts for making fine-tuning dataset (LLM as a Judge)

# %%
constant_system_message = """
You are senior scientist in plant biology. You NEED to meticulously VALIDATE given clustering output, and provide a corrected clustering if needed. Explain which groupings are wrong and provide final output. You MUST write response like a senior human plant scientist.

The following are the entity clustering guidelines:
	1.	Exact Phrase Matching Matters: Always consider the full phrase, including key biological terms, bracketed text (ignoring minor differences such as spacing, punctuation, correct abbreviations, plurality).
	2.	Strict (100%) Key Term Separation: Entities with different biological terms MUST be placed in separate clusters.
3. Sub-identifier separation: Separate Entities with numeric differences, sub-identifiers, or qualifiers into different groups.
	4.	Avoid False Similarity: Do NOT cluster two items together in same group just because they share a common word or term.
	5.	Strict Synonym/Near-Synonym Grouping: Only group entities that refer to the same biological structure, process, meaning or concept.
	6.	Maintain 100% Precision: When in even small doubt, MUST place entities in separate clusters.
	7.	Preserve Original Data: No new items should be introduced, no duplicates should be introduced, and no entities should be omitted.
8. YOU MUST pickup most appropriate and easy-to-understand cluster representative and enclose it with '**', if there is more than one entity in that particular cluster. For example, pick the full term instead of an abbreviation.
	9.	Output Format: Always return results in valid JSON format. MUST USE GIVEN KEY.

Your main task is to read the clustered entities and output the validation in the below mentioned format.

The goal:
These results came from a smaller LLM, and i want you to take a look at it.
With your expertise in plant biology, generate prompts for fine-tuning the smaller LLM and mimick your patterns for this specific task.
I want you to validate the clustering of this smaller model, and provide a corrected clustering if needed.
Then you should imagine that you are a human plant biology senior scientist who explains to the smaller LLM what it is doing wrong, to give it the final output. You should never mention the smaller LLM, but instead just pretend you are a human user. 
An example of this would be:
'I think you are wrong, cluster X is actually different from cluster Y because of so and so reasons. Cluster X and Y should be clustered seperately'.
If the smaller model is correct however, you should write something like:
'Great job, that looks correct because of so and so reasons. Now output the correct format, but only output clusters with more than one member.'
The expected input format:

{
  "submission_id_1": {
    "clusters": [
      [
        "**cluster_item1**",
        "cluster_item2"
      ],
      [
        "cluster_item3"
      ]
    ]
  }
}

Return format:

If the clustering is correct:
{
  "submission_id_1": {
    "is_correct": "True",
    "user_prompt": "This looks correct to me, output the clusters that have more than 1 member in the correct json format.",
    "clusters": [
      [
        "cluster_item1",
        "cluster_item2"
      ]
    ]
  }
}

If the clustering is incorrect:

{
  "submission_id_1": {
    "is_correct": "False",
    "user_prompt": "This looks incorrect to me, <insert reason here>. Output the clusters that have more than 1 member in the correct json format.",
    "clusters": [
      [
        "cluster_item2",
        "cluster_item3"
      ]
    ]
  }
}

Warnings:

Be completely sure to not forget any nodes from the input list.
Remember not to base corrections on higher domain level knowledge, that the smaller model might not have, but rather the semantic meaning of the terms.
is_correct should be returned as a string "True" or "False", and only one of these two.
If there is any doubt if two groups should cluster together, cluster them separately.
Remember to select group representative by enclosing entity in "**"

"""

# %%
constant_user_message = """  
Here are 2 examples of validation behavior:

Example 1, correct behavior:

input:
{120406: ['difficulty in detecting mutations [phenotype]', 'hereditary breast cancers [phenotype]', 'mutational status of parental tumor cells [phenotype]', 'certain mutation types [phenotype]', 'Well-characterized mutations [phenotype]', 'alternative classifications [phenotype]', 'unique molecular signature [phenotype]', 'oncological diseases [phenotype]', 'independent mutation data [phenotype]', 'inherited disease mutation databases [database]', 'mutational signatures [mutation]', 'mutation types [phenotype]', 'More than half of human cancers [phenotype]', 'somatic and germline mutations [phenotype]', 'Identified mutations [phenotype]', 'lung cancer patients [phenotype]', 'germline transmissible [phenotype]', 'mutations in the germline [phenotype]', 'sporadic breast cancers [phenotype]', 'segregating mutations [phenotype]', 'breast/ovarian cancers [phenotype]', 'non-small-cell lung carcinoma [phenotype]', 'inherited breast cancer cases [phenotype]', 'tumour-specific aberrations [phenotype]', 'list of likely candidate mutations [phenotype]', 'germline-transmitted mutations [phenotype]', 'systematic asymmetries in heritable mutations [genetic feature]', 'targeted heritable mutations [phenotype]', 'fixed mutations in ancestral line [phenotype]', 'various types of mutation [phenotype]', 'several types of mutation [phenotype]', 'screening of these exons [phenotype]', 'many human cancers [phenotype]', 'difficulties to differentiate mutations [phenotype]', 'base substitutions, deletions, insertions, and translocations [phenotype]', 'specific mutational classes [phenotype]', 'germline mutations [phenotype]', 'other types of mutation [phenotype]', 'unmasking of deleterious mutations [phenotype]']}

Explanation of correct clustering:

["**germline mutations [phenotype]**", "germline-transmitted mutations [phenotype]", "mutations in the germline [phenotype]", "germline transmissible [phenotype]"] all describe inheritable genetic alterations passed from one generation to the next.
["More than half of human cancers [phenotype]", "**oncological diseases [phenotype]**", "many human cancers [phenotype]"] reference broad groups of malignant diseases occurring in humans.
["**mutation types [phenotype]**", "base substitutions, deletions, insertions, and translocations [phenotype]", "various types of mutation [phenotype]", "several types of mutation [phenotype]", "other types of mutation [phenotype]", "certain mutation types [phenotype]", "specific mutational classes [phenotype]"] collectively describe or list categories of genetic changes.
["difficulties to differentiate mutations [phenotype]", "**difficulty in detecting mutations [phenotype]**"] denote challenges in identifying or distinguishing specific genetic variants.
["inherited breast cancer cases [phenotype]", "**hereditary breast cancers [phenotype]**"] explicitly point to breast cancer instances where genetic risk is inherited.
Notes on Separation Certain single-element entries might share partial similarity, such as "somatic and germline mutations [phenotype]" or "targeted heritable mutations [phenotype]," but remain separate because of additional qualifiers or exact term differences

Example 2, incorrect clustering:
input:
{"165162": [["**internalized cargo [metabolite]**", "endocytosed material [metabolite]", "Internalized cargoes [metabolite]"], ["**Internalization of endocytic tracer FM4-64 [metabolite]**", "internalisation of an endocytic tracer dye [metabolite]"], ["endocytosis of transferrin [metabolite]"], ["cellular uptake of 14 chemicals [metabolite]"]]}

Explanation of incorrect behavior:

["**internalized cargo [metabolite]**", "endocytosed material [metabolite]", "Internalized cargoes [metabolite]"] all describe general endocytic cargo without specifying particular molecules or numeric differences.
["**Internalization of endocytic tracer FM4-64 [metabolite]**", "internalisation of an endocytic tracer dye [metabolite]"] are clustered wrong, one specifically mentions FM4-64, while the other refers generally to any tracer dye, and they should therefore be separated following strict separation rules.

Now read the cluster, validate and output the desired format:
"""

# %% [markdown]
# ## Prompts for finetuning dataset (v5)

# %%
system_message = """You are senior scientist in plant biology. You NEED to meticulously do reasoning and then cluster given input, and provide the reasoning followed by clusters based on the reasoning performed.

The following are the entity clustering guidelines:
	1.	Exact Phrase Matching Matters: Always consider the full phrase, including key biological terms, bracketed text (ignoring minor differences such as spacing, punctuation, correct abbreviations, plurality).
	2.	Strict (100%) Key Term Separation: Entities with different biological terms MUST be placed in separate clusters.
3. Sub-identifier separation: Separate Entities with numeric differences, sub-identifiers, or qualifiers into different groups.
	4.	Avoid False Similarity: Do NOT cluster two items together in same group just because they share a common word or term.
	5.	Strict Synonym/Near-Synonym Grouping: Only group entities that refer to the same biological structure, process, meaning or concept.
	6.	Maintain 100% Precision: When in even small doubt, MUST place entities in separate clusters.
	7.	Preserve Original Data: No new items should be introduced, no duplicates should be introduced, and no entities should be omitted.
8. YOU MUST pickup most appropriate and easy-to-understand cluster representative and enclose it with '**', if there is more than one entity in that particular cluster. For example, pick the full term instead of an abbreviation. MUST mention this in reasoning statement.
	9.	Output Format: Always return results in valid JSON format. MUST USE GIVEN KEY.
10. Discard Single-element Clusters: Remove any cluster that ends up with only one entity.

Your main task is to read the input, do reasoning and output the reasoning and the correct clusters in a valid JSON object format. Input is a json object with given key and the value is the list of biological entities. The output is a json object with given key and the values are two json objects: reasoning and corresponding clustered entities (list of lists where each inner list is one cluster).

"""

# %%
detailed_description = """
Input-1

{
  "0": [
    "meiotic arrest [phenotype]",
    "delayed/arrested meiosis [phenotype]",
    "absence of meiotic arrest [phenotype]",
    "meiotic prophase arrest [phenotype]",
    "males arresting in the middle of prophase I [phenotype]",
    "early arrest [phenotype]",
    "leptotene arrest [phenotype]",
    "pachytene arrest [phenotype]",
    "arrest in late prophase I [phenotype]",
    "meiosis I arrest [phenotype]",
    "meiotic arrest at telophase I [phenotype]",
    "male meiosis until the end of the first division [phenotype]",
    "termination of meiosis after anaphase I [phenotype]",
    "meiotic arrest in anaphase II [phenotype]",
    "arrested zygotic divisions [phenotype]",
    "arrested endosperm nuclear divisions [phenotype]",
    "arrest of the first mitotic division in gametogenesis [phenotype]",
    "arresting prior to the first mitotic division [phenotype]",
    "mitotic arrest during female gametogenesis [phenotype]"
  ]
}

Clustered entities given input-1:

{
  "0": [
    [
      "Meiotic block [phenotype]",
      "**meiotic arrest [phenotype]**",
      "meiotic arrest phenotype [phenotype]",
      "meiotic division stop [phenotype]"
    ],
    [
      "block in meiosis prophase I [phenotype]",
      "**meiotic prophase arrest [phenotype]**"
    ],
    [
      "**pachytene arrest [phenotype]**",
      "meiotic arrest at pachytene [phenotype]"
    ],
    [
      "arrest at the end of meiosis I [phenotype]",
      "arrest after meiosis I [phenotype]",
      "**meiotic arrest at telophase I [phenotype]**"
    ],
    [
      "**termination of meiosis after anaphase I [phenotype]**",
      "premature termination of meiosis after anaphase I [phenotype]"
    ],
    [
      "arrest of meiotic progression in anaphase II [phenotype]",
      "**meiotic arrest in anaphase II [phenotype]**"
    ],
    [
      "arresting the first mitosis during gametogenesis [phenotype]",
      "**arrest of the first mitotic division in gametogenesis [phenotype]**",
      "FNM half-stop [phenotype]"
    ]
  ]
}

Output-1:
{
  "0": {
    "reasoning": "All synonyms describing a complete, generic meiotic halt have to be clustered under **'meiotic arrest [phenotype]'** because they share the same meaning for an unspecified block. Broader prophase I arrests must merge into **'meiotic prophase arrest [phenotype]'** to group all general prophase I blocks without substage detail. Any pachytene-specific terms must fall under **'pachytene arrest [phenotype]'** to capture the unique arrest at the fully synapsed stage. Arrests at the end of meiosis I must be collected under **'meiotic arrest at telophase I [phenotype]'** so that the precise transition at telophase I is clearly indicated. Post–anaphase I failures must be grouped as **'termination of meiosis after anaphase I [phenotype]'** to highlight that the process ends immediately following homolog separation. Anaphase II stalls have to be assigned to **'meiotic arrest in anaphase II [phenotype]'** in order to specify a distinct block during sister chromatid separation. Finally, blocks in the first post–meiotic mitosis must form the cluster **'arrest of the first mitotic division in gametogenesis [phenotype]'** because they occur right after meiosis is completed. Any single-term categories remain excluded from the final output, as each must contain at least two synonymous labels to be shown."
  }
}


Input-2
{
  "2": '[
    "Salt-stress severity [treatment]",
    "high NaCl stress [treatment]",
    "potassium deprivation stress [treatment]",
    "salt-stress response [treatment]",
    "salt stress tolerance [treatment]",
    "heat and salt stress conditions [treatment]",
    "prolonged levels of salt stress [treatment]",
    "recovery from salt stress [treatment]",
    "salt stress assay [treatment]",
    "salt stress signaling pathways [treatment]",
    "gradual salt stress treatments [treatment]",
    "salt and low temperature stresses [treatment]",
    "salt and silicon stresses [treatment]"
  ]'
}

clustered entities for given input-2
{
  "2": [
    [
      "Salt-stress severity [treatment]",
      "**high NaCl stress [treatment]**",
      "salt-stress response [treatment]",
      "salt stress tolerance [treatment]",
      "prolonged levels of salt stress [treatment]",
      "recovery from salt stress [treatment]",
      "salt stress assay [treatment]",
      "salt stress signaling pathways [treatment]",
      "gradual salt stress treatments [treatment]"
    ]
  ]
}

Output-2:
{
  "2": {
    "reasoning": "All treatments that involve only salt (NaCl) must be clustered under **'high NaCl stress [treatment]'** because they focus on the same abiotic stress factor (NaCl) without additional conditions. Each label—such as 'Salt-stress severity,' 'salt-stress response,' or 'salt stress tolerance'—addresses NaCl-induced stress exclusively, which justifies grouping them together. Single-term items mixing salt with other factors (e.g., heat, low temperature, or silicon) or an entirely different stress (e.g., potassium deprivation) must remain separate because their conditions differ fundamentally from pure NaCl stress. Consequently, any single-term clusters are omitted from the final output unless they contain multiple synonymous labels."
  }
}
"""

# %%
#sample 25 rows from the dataframe where one_item is False and also sample another 25 rows where one_item is True
df_one_item = df[df['one_item'] == True].sample(25)
df_not_one_item = df[df['one_item'] == False].sample(25)

#concatenate the two dataframes
df_final = pd.concat([df_one_item, df_not_one_item])
#randomize the order of the rows
df_final = df_final.sample(frac=1)
df_final = df_final.reset_index(drop=True)

# %%
df_final
# Out:
#     Entity Name                                              Input  \
# 0        109139  {"109139": ["satC core promoter for (-)-strand...
# 1         87406  {"87406": ["little to no training [treatment]"...
# 2        100596  {"100596": ["woody flowering plant(s) [organis...
# 3         78873  {"78873": ["chaperonin 60 subunit beta 2 [prot...
# 4         29577  {"29577": ["pre-ribosome export [process]", "p...
# 5        122504  {"122504": ["same role [phenotype]", "similar ...
# 6        101327  {"101327": ["volatiles emitted by A. thaliana ...
# 7         63504  {"63504": ["PsaB-PsaI-PsaH side of PSI [protei...
# 8         63849  {"63849": ["manganese-binding polypeptides [pr...
# 9           664  {"664": ["last stages of mite development [phe...
# 10       143138  {"143138": ["VDOF2 [protein]", "VDOP1 [protein...
# 11        32886  {"32886": ["future position of the new cell wa...
# 12       111625  {"111625": ["sequences between -3604 and -3563...
# 13        30540  {"30540": ["engineers [person]", "expert knowl...
# 14       149112  {"149112": ["BnaMYB21 [gene]", "cnu_m244a [gen...
# 15       108934  {"108934": ["hyper-up gene(s) [gene]", "hyperm...
# 16       140128  {"140128": ["CAMTA1 dependent positively regul...
# 17       102196  {"102196": ["vacuolar-enriched membranes of A....
# 18       141136  {"141136": ["pAsr1491 [gene]", "pAsr1755 [gene...
# 19       135617  {"135617": ["mitochondrial electron transport ...
# 20       168604  {"168604": ["elevated levels of endogenous 9-N...
# 21         1979  {"1979": ["embryos at pre-globular and globula...
# 22       126710  {"126710": ["transition of plant(s) chromosoma...
# 23        10829  {"10829": ["direct antagonism [phenotype]", "d...
# 24        28668  {"28668": ["regions of active transport [tissu...
# 25       101253  {"101253": ["200 Gy-treated A. thaliana [organ...
# 26        88364  {"88364": ["improved algorithms [treatment]", ...
# 27        72373  {"72373": ["UMAMIT uniporters [protein]", "Amm...
# 28       103231  {"103231": ["yeast strain YK44 [organism]", "y...
# 29         3539  {"3539": ["effective survival strategies [phen...
# 30       114243  {"114243": ["expression in rice [process]", "i...
# 31       155976  {"155976": ["only SIP1 homologue [gene]", "SiP...
# 32         7573  {"7573": ["Increased human population [phenoty...
# 33       121095  {"121095": ["transformation with NLPPya or NLP...
# 34       130281  {"130281": ["A. thaliana pre-tRNA(Tyr) [gene]"...
# 35       101782  {"101782": ["Goettingen-7 [organism]", "access...
# 36        92876  {"92876": ["biopesticide [treatment]", "potent...
# 37        52510  {"52510": ["21,570 gene(s) [gene]", "21,359 ge...
# 38        42267  {"42267": ["Abstinence by mutual consent (amc)...
# 39        82013  {"82013": ["unique mitochondrial protein(s) [p...
# 40       128564  {"128564": ["43 AaMADS putative gene(s) [gene]...
# 41       133452  {"133452": ["tannin deficient seed 4 [gene]", ...
# 42        41639  {"41639": ["eleven M<sub>3</sub> A. thaliana l...
# 43        38783  {"38783": ["HVA1-P line [mutant]", "Chl accumu...
# 44        52882  {"52882": ["BR receptor complex [gene]", "seco...
# 45        75945  {"75945": ["domain I of IAA17 [protein domain]...
# 46        96226  {"96226": ["leaf blades, nodules, and buds [or...
# 47       114365  {"114365": ["3 s every 3 min [phenotype]", "th...
# 48         2276  {"2276": ["F1 trichome phenotype [phenotype]",...
# 49        14243  {"14243": ["abnormally flattened siliques [phe...
#
#                                                Output  \
# 0   {"109139": [["119 bp minimal promoter region [...
# 1   {"87406": [["favorite textbook [education]"], ...
# 2   {"100596": [["**woody flowering plant(s) [orga...
# 3   {"78873": [["chaperonin 60 subunit beta [prote...
# 4   {"29577": [["ribosome export [process]", "**pr...
# 5   {"122504": [["same role [phenotype]", "similar...
# 6   {"101327": [["**endophyte-inoculated A. thalia...
# 7   {"63504": [["anti-PsaA antibodies [protein]"],...
# 8   {"63849": [["DCH model [phenotype]"], ["**mang...
# 9   {"664": [["mature females that emerged [phenot...
# 10  {"143138": [["VDOP1 [protein]"], ["VDOF2 [prot...
# 11  {"32886": [["site of cell wall fusion [subcell...
# 12  {"111625": [["sequences between -3604 and -356...
# 13  {"30540": [["engineers [person]"], ["optics [d...
# 14  {"149112": [["cnu_m244a [gene]"], ["BnGPT1-A2 ...
# 15  {"108934": [["hyper-up gene(s) [gene]"], ["hyp...
# 16  {"140128": [["CAMTA1 dependent positively regu...
# 17  {"102196": [["A. thaliana root(s) endodermis [...
# 18  {"141136": [["pAsr11779 [promoter]"], ["pAsr14...
# 19  {"135617": [["coordinately regulated gene(s) f...
# 20  {"168604": [["elevated levels of 9-NAE-HOD [me...
# 21  {"1979": [["Preglobular embryos [phenotype]"],...
# 22  {"126710": [["transition of plant(s) chromosom...
# 23  {"10829": [["direct antagonism [phenotype]"], ...
# 24  {"28668": [["transport zones [organ]"], ["**re...
# 25  {"101253": [["irradiated seeds of A. thaliana ...
# 26  {"88364": [["low-cost methodology [treatment]"...
# 27  {"72373": [["**Ammonium transporters [protein]...
# 28  {"103231": [["**yeast strain 9.3 [organism]**"...
# 29  {"3539": [["pro-survival strategy [phenotype]"...
# 30  {"114243": [["overexpression analyses [process...
# 31  {"155976": [["SIP [gene]"], ["SIP1 [gene]"], [...
# 32  {"7573": [["swelling population [phenotype]", ...
# 33  {"121095": [["modifying FIL [gene]"], ["In pla...
# 34  {"130281": [["A. thaliana PRORP2 [gene]"], ["t...
# 35  {"101782": [["Goettingen-7 [organism]"], ["Goe...
# 36  {"92876": [["**biopesticides [treatment]**", "...
# 37  {"52510": [["21 gene(s) [gene]"], ["21,912 gen...
# 38  {"42267": [["Abstinence by mutual consent (amc...
# 39  {"82013": [["protein(s) upregulated in the mit...
# 40  {"128564": [["34 MFS gene(s) [gene]"], ["57 MA...
# 41  {"133452": [["Thalianol gene(s) cluster [genom...
# 42  {"41639": [["20 A. thaliana lines [mutant]"], ...
# 43  {"38783": [["COM lines [mutant]"], ["AEQsig6 s...
# 44  {"52882": [["BRCT-containing gene(s) [gene]"],...
# 45  {"75945": [["EBD [protein domain]"], ["ES doma...
# 46  {"96226": [["D. nobile leaf [organ]"], ["leaf ...
# 47  {"114365": [["CBF3 phase and waveform [phenoty...
# 48  {"2276": [["F1 trichome phenotype [phenotype]"...
# 49  {"14243": [["short and curled siliques [phenot...
#
#                                              Output>1  one_item
# 0   {"109139": [["pTRY-B fragment [genomic region]...     False
# 1                                       {"87406": []}      True
# 2   {"100596": [["**woody flowering plant(s) [orga...     False
# 3                                       {"78873": []}      True
# 4   {"29577": [["ribosome export [process]", "**pr...     False
# 5   {"122504": [["same role [phenotype]", "similar...     False
# 6   {"101327": [["**endophyte-inoculated A. thalia...     False
# 7   {"63504": [["PsaL protein(s) levels [protein]"...     False
# 8   {"63849": [["**manganese cluster [protein comp...     False
# 9   {"664": [["mature females that emerged [phenot...     False
# 10                                     {"143138": []}      True
# 11  {"32886": [["site of cell wall fusion [subcell...     False
# 12                                     {"111625": []}      True
# 13                                      {"30540": []}      True
# 14                                     {"149112": []}      True
# 15                                     {"108934": []}      True
# 16  {"140128": [["**upregulated CKX gene(s) [gene]...     False
# 17  {"102196": [["**A. thaliana root(s) plasma mem...     False
# 18                                     {"141136": []}      True
# 19  {"135617": [["coordinately regulated gene(s) f...     False
# 20  {"168604": [["elevated levels of 9-NAE-HOD [me...     False
# 21                                       {"1979": []}      True
# 22                                     {"126710": []}      True
# 23                                      {"10829": []}      True
# 24  {"28668": [["**regions of active transport [ti...     False
# 25                                     {"101253": []}      True
# 26  {"88364": [["low-cost methodology [treatment]"...     False
# 27  {"72373": [["**Ammonium transporters [protein]...     False
# 28  {"103231": [["**yeast strain 9.3 [organism]**"...     False
# 29  {"3539": [["pro-survival strategy [phenotype]"...     False
# 30  {"114243": [["blueberry expression analyses [p...     False
# 31  {"155976": [["**AtDIR1-like [gene]**", "DIR1-l...     False
# 32  {"7573": [["swelling population [phenotype]", ...     False
# 33                                     {"121095": []}      True
# 34                                     {"130281": []}      True
# 35  {"101782": [["accession Dijon-G (Di-G) [organi...     False
# 36  {"92876": [["**biopesticides [treatment]**", "...     False
# 37                                      {"52510": []}      True
# 38                                      {"42267": []}      True
# 39  {"82013": [["**protein(s) localized to mitocho...     False
# 40                                     {"128564": []}      True
# 41                                     {"133452": []}      True
# 42                                      {"41639": []}      True
# 43                                      {"38783": []}      True
# 44                                      {"52882": []}      True
# 45  {"75945": [["**ETR1 receiver domain [protein d...     False
# 46                                      {"96226": []}      True
# 47                                     {"114365": []}      True
# 48                                       {"2276": []}      True
# 49                                      {"14243": []}      True

# %%
df_final['one_item'].value_counts()
# Out:
# one_item
# False    25
# True     25
# Name: count, dtype: int64

# %%
df
# Out:
#      Entity Name                                              Input  \
# 0          58963  {"58963": ["Gardea-Torresdey et al. [researche...
# 1          22775  {"22775": ["physiological transport of macro-m...
# 2          22996  {"22996": ["stomatal conductance analyses [phe...
# 3         100116  {"100116": ["modern clade [gene]", "modern cla...
# 4         133255  {"133255": ["Plastidic LPPs [gene]", "PLSP2B [...
# ..           ...                                                ...
# 995        31615  {"31615": ["auxin-regulated endocytosis [proce...
# 996       157227  {"157227": ["SlSAUR1-like [gene]", "ZmSAUR1 [g...
# 997       131559  {"131559": ["BtuC gene(s) [gene]", "BtuN gene(...
# 998        99091  {"99091": ["O. fragrans 'Liuyejingui' (OFL) [o...
# 999        65306  {"65306": ["CO/NF-YB/NF-YC trimer complex [pro...
#
#                                                 Output  \
# 0    {"58963": [["Gardea-Torresdey et al. [research...
# 1    {"22775": [["substance that could be transloca...
# 2    {"22996": [["**transpiration and stomatal cond...
# 3    {"100116": [["Clade M [clade]"], ["Clade SL [c...
# 4    {"133255": [["**PLSP2A [gene]**", "PLSP2A gene...
# ..                                                 ...
# 995  {"31615": [["auxin-mediated modulation of the ...
# 996  {"157227": [["GmSAUR [gene]"], ["StSAUR [gene]...
# 997  {"131559": [["BtuB gene(s) [gene]"], ["BtuC ge...
# 998  {"99091": [["Genome sequencing of O. fragrans ...
# 999  {"65306": [["**CO/NF-Y complex [protein comple...
#
#                                               Output>1  one_item
# 0                                        {"58963": []}      True
# 1    {"22775": [["**transportation [phenotype]**", ...     False
# 2    {"22996": [["**transpiration and stomatal cond...     False
# 3                                       {"100116": []}      True
# 4    {"133255": [["**PLSP2A [gene]**", "PLSP2A gene...     False
# ..                                                 ...       ...
# 995  {"31615": [["auxin-dependent inhibition of end...     False
# 996  {"157227": [["ZmSAUR1 (Zea mays SAURs) [gene]"...     False
# 997                                     {"131559": []}      True
# 998  {"99091": [["**O. fragrans 'Liuyejingui' (OFL)...     False
# 999  {"65306": [["**CO/NF-Y complex [protein comple...     False
#
# [1000 rows x 5 columns]

# %%
entity_dict = {}
for item in df["Output"]:
    try:
        parsed_dict = json.loads(item)
        entity_dict.update(parsed_dict)
    except json.JSONDecodeError:
        print(f"Skipping invalid JSON: {item}")

# %%
import ast

def split_dict(d, chunk_size=100):
    keys = list(d.keys())
    chunks = []
    for i in range(0, len(keys), chunk_size):
        chunk_keys = keys[i:i+chunk_size]
        chunk_dict = {k: d[k] for k in chunk_keys}
        chunks.append(chunk_dict)
    return chunks

def flatten_bracketed_strings(value_list):
    """
    Takes a list. For each item:
      - If item is a string that looks like '[...]', parse it and extend the list.
      - Otherwise, keep as is.
    Returns a new flattened list.
    """
    new_list = []
    for val in value_list:
        if (
            isinstance(val, str) 
            and val.strip().startswith("[") 
            and val.strip().endswith("]")
        ):
            # Attempt to parse the bracketed string
            try:
                parsed = ast.literal_eval(val)  # convert string -> Python list
                if isinstance(parsed, list):
                    new_list.extend(parsed)  # flatten
                else:
                    # If it's not a list, just append as-is
                    new_list.append(val)
            except (SyntaxError, ValueError):
                # If parsing fails, keep original
                new_list.append(val)
        else:
            new_list.append(val)
    return new_list



chunks = split_dict(entity_dict, 1) # Use batch size of 1
print('Number of chunks:',len(chunks))
# Out:
# Number of chunks: 1000

# %%
for chunk in chunks:
    print(chunk)
    print('-------------------')
# Out:
# {'58963': [['Gardea-Torresdey et al. [researcher]'], ['Barrena et al. [researcher]']]}
# -------------------
# {'22775': [['substance that could be translocated [phenotype]'], ['transport of metabolites [phenotype]'], ['**transportation [phenotype]**', 'transportion [phenotype]'], ['transport of intermediates [phenotype]'], ['dye transport [phenotype]'], ['transport issues [phenotype]'], ['As transport [phenotype]'], ['transport and distribution throughout the plant(s) [phenotype]'], ['traffic [phenotype]'], ['transport within the plant(s) [phenotype]', 'transport through the plant(s) [phenotype]', '**transport in planta [phenotype]**'], ['secondary metabolites transportation [phenotype]', '**secondary metabolite transport [phenotype]**'], ['systemic movement via the phloem [phenotype]'], ['transport of compounds [phenotype]'], ['changes in transport rates [phenotype]'], ['chemical transport [phenotype]'], ['glucosinolates transport [phenotype]'], ['**photoassimilate transport [phenotype]**', 'transport of photo-assimilates [phenotype]'], ['transport of matter [phenotype]'], ['transportation of terpenoids [phenotype]'], ['transport phenomena [phenotype]'], ['transport and accumulation of metabolites [phenotype]'], ['**enzyme transport [phenotype]**', 'transport of enzymes [phenotype]'], ['transport events [phenotype]'], ['transportation of lignin [phenotype]'], ['spatiotemporal transport in intact plant(s) [phenotype]'], ['physiological transport of macro-molecules [phenotype]'], ['transport of chlorophyll metabolites [phenotype]'], ['transport among different tissues [phenotype]'], ['biochemical transport [phenotype]'], ['transport changes [phenotype]'], ['uptake and translocation within plant(s) [phenotype]']]}
# -------------------
# {'22996': [['**transpiration and stomatal conductance values [phenotype]**', 'E and g s [phenotype]'], ['consideration of stomatal conductance [phenotype]', '**stomatal conductance measurements [phenotype]**', 'measured stomatal conductance [phenotype]', 'Conductance measurements [phenotype]', 'stomatal conductances [phenotype]', 'direct measurements of g s [phenotype]', 'stomatal conductance analyses [phenotype]', 'conductance levels [phenotype]', 'measuring stomatal conductance [phenotype]'], ['derived model [phenotype]'], ['engineering stomatal conductance [phenotype]'], ['K(leaf) values [phenotype]'], ['stomatal conductance, transpiration rate, hydraulic conductivity and photosynthetic efficiency [phenotype]'], ['AtPIP2;5 regulating gm [phenotype]'], ['kinetic stomatal conductance analyses [phenotype]', '**time-resolved stomatal conductance analyses [phenotype]**', 'time-resolved measurements of stomatal conductance [phenotype]'], ['number of open stomata and amount of water loss through transpiration [phenotype]'], ['stomatal conductance, transpiration rate, relative-water content of plant(s) leaf [phenotype]'], ['WUE and Stomatal conductance [phenotype]'], ['both SD and photosynthetic gas exchange traits [phenotype]'], ['regulation of stomatal conductance through FER [phenotype]'], ['methods to quickly assess the stomatal conductance (gₛ) [phenotype]']]}
# -------------------
# {'100116': [['Clade M [clade]'], ['Clade SL [clade]'], ['Clade SH [clade]'], ['Clade U [clade]'], ['modern clade [gene]'], ['modern clade WOX members [gene]']]}
# -------------------
# {'133255': [['**PLSP2A [gene]**', 'PLSP2A gene(s) [gene]'], ['PLSP2 [gene]'], ['PLSP2B [gene]'], ['LPP2 [gene]'], ['LPE1 [gene]'], ['**LPP gamma [gene]**', 'LPPႰ [gene]'], ['LPPႱ [gene]'], ['LPPႲ [gene]'], ['Plastidic LPPs [gene]'], ['ptLPD2 [gene]'], ['SUPPRESSOR OF LLP1 1 (SOL1) [gene]'], ['HvLPP1 [gene]'], ['HvLPP2 [gene]'], ['PSPTO3648 [gene]'], ['cyanobacterial LPP [gene]']]}
# -------------------
# {'2276': [['F1 trichome phenotype [phenotype]'], ['near-full hybrid NFH3 [phenotype]'], ['F25H stressed progeny [phenotype]'], ['R1 progenies [phenotype]'], ['Mendelian segregation in the F1 generation [phenotype]'], ['fc2 phenotypes [phenotype]'], ['production of normal F2 seeds [phenotype]'], ['dwarf F2 plant(s) [phenotype]'], ['phenotypically normal F2 progeny [phenotype]'], ['wild-type phenotype F1 plant(s) [phenotype]'], ['100% F1 progeny [phenotype]'], ['wt progeny from F3 progeny pools [phenotype]'], ['white F2 progeny [phenotype]'], ['white panicle phenotype in F1 progeny [phenotype]'], ['most of the S1 progeny [phenotype]']]}
# -------------------
# {'65264': [['MYC2-JAZ-NINJA-TPL complex [protein complex]'], ['**JAZ/NINJA/TPL repressor complex [protein complex]**', 'TPL-NINJIA-JAZ complex [protein complex]'], ['Myc-TPL [protein]'], ['Carbon Catabolite Repression 4-Negative on TATA-less (NOT) complex subunit NOT2 [protein]'], ['TCP Topless EAR repressor complexes [protein complex]'], ['TPR1-TPR2 complex [protein complex]'], ['Tup1 [protein complex]'], ['TOPLESS-RELATED (TPR1-4) [protein complex]'], ['TPL family [protein complex]'], ['WOX-TPL repressor complex [protein complex]'], ['CDF-TPL transcriptional complex [protein complex]'], ['LUH-SLK2 complex [protein complex]'], ['BAH-PHD-CPL2 [protein complex]'], ['BAH-PHD-CPL2 pathway [process]'], ['Suppressor of Ty (SPT) module [protein complex]'], ['subnetwork with double-negative feedback via TF monomers [protein complex]'], ['TPL-related protein(s) complex [protein]'], ['**TPL/TPR [protein complex]**', 'TPL-TPR complexes [protein complex]', 'TPL/TPRs [protein complex]'], ['TPL oligomer [protein complex]'], ['NINJA/TOPLESS transcriptional co-repressor complex [protein complex]'], ['NINJA-TPL [protein]'], ['binding to NINJA/TPL repressor complex [protein complex]'], ['recruitment of corepressor NINJA [protein]'], ['TIE1 and TPL/TPRs [protein complex]'], ['TPL/TPR repressor complex [protein complex]'], ['TPL/TPR trimeric complex [protein complex]'], ['TPL-AtMed21 interaction [protein complex]'], ['TOPLESS (TPL) co-repressor complex [protein complex]'], ['docking point for TPL-HDAC complex [protein complex]'], ['five members of the TPL/Groucho/TLE co-repressor family [protein complex]'], ['TOPLESS repressive complex [protein complex]'], ['TPL/TPR1 [protein complex]'], ['TPL/TPR co-repressor activity [protein complex]'], ['TPL/TPR co-repressors [protein complex]'], ['TOPLESS complex [protein complex]']]}
# -------------------
# {'82106': [['mammalian isoforms [organism]'], ['multiple isoforms in metazoans [organism]'], ['yeast isoforms [organism]'], ['copies of eIF(iso)4E [protein]'], ['multiple forms in mammals [protein]'], ['isoforms and organisms [organism]'], ['more than one eIF4E protein(s) forms [protein]'], ['complex isoform distribution [protein]'], ['isoforms of many species [organism]'], ['many isoforms [protein]'], ['isoforms from animals and yeast [organism]']]}
# -------------------
# {'169694': [['reduced accumulation of fumarate [metabolite]'], ['small loss of non-photoactive plastoquinone-9 [metabolite]'], ['zeatin accumulation relieved [metabolite]'], ['reduced production of volatiles [metabolite]'], ['small increase in pyrimidine intermediates [metabolite]'], ['decreased production of phloretic acid [metabolite]'], ['slight decrease in vernolic acid accumulation [metabolite]']]}
# -------------------
# {'33354': [['**mitochondrial redox status [subcellular compartment]**', 'redox status of mitochondria [subcellular compartment]', 'Redox state in mitochondria [subcellular compartment]', 'redox status of the mitochondria [subcellular compartment]', 'redox status in the mitochondria [subcellular compartment]', 'mitochondrial redox homeostasis [subcellular compartment]', 'mitochondria redox states [subcellular compartment]'], ['oxidation in mitochondria [subcellular compartment]'], ['**Fewer mitochondria [subcellular compartment]**', 'decrease in number of mitochondria [subcellular compartment]', 'decrease in mitochondria [subcellular compartment]', 'reduced number of mitochondria [subcellular compartment]', 'number of less efficient mitochondria [subcellular compartment]'], ['ROS homeostasis in mitochondria [subcellular compartment]']]}
# -------------------
# {'89650': [['Elevated auxin response [metabolite]'], ['Al stress-induced auxin synthesis [metabolite]'], ['Al-induced auxin accumulation [metabolite]'], ['increases in auxin sensitivity [metabolite]'], ['altered sensitivities to auxin [plant hormone]'], ['Al-induced auxin accumulation in root(s) TZ [metabolite]'], ['increased auxin content in root(s) apical meristem zone [tissue]'], ['extreme sensitivities to exogenous auxin [metabolite]']]}
# -------------------
# {'156043': [['FLIP [gene]'], ['**HEI10 gene(s) [gene]**', 'E3 ligase HEI10 [gene]', 'Pro-crossover E3 ligase HEI10 [gene]']]}
# -------------------
# {'116946': [['OTU157779 abundance [organism]'], ['SynCom size [phenotype]'], ['UV fractograms [phenotype]'], ['number of clones [phenotype]'], ['total UMI counts [phenotype]'], ['number of nuclear DNA-containing clones on each macroarray [phenotype]'], ['**quantification results [phenotype]**', 'actual numbers obtained in the assays [phenotype]'], ['H2Bub levels [metabolite]'], ['**7634 colony-forming units [phenotype]**', '520 colonies [phenotype]'], ['CT values of 72 samples [phenotype]'], ['3UI-Ts densities [phenotype]'], ['OM samples [phenotype]'], ['number and relative abundance of transcripts [phenotype]']]}
# -------------------
# {'93624': [['haploid microspores [cell type]'], ['**microspore mother cells [cell type]**', 'microspore mother cells from undergoing meiosis [cell type]', 'microspore mother cells (MMC) [cell type]'], ['**microspores [organism]**', 'Microspore [organism]', 'microspores/pollen [organism]'], ['2n Microspores [gamete]'], ['Micropylar megaspore [structure]'], ['Microspores derived from imaged meiocytes [organ]'], ['Microspore nucleus [organ]'], ['Sister microspores [cell type]'], ['Developing microspores [cell type]'], ['pollen mitosis I [process]'], ['Haploid microspore [organ]'], ['Microspore [organ]'], ['Micropylar end of the megagametophyte [organ]'], ['microsporocyte [organ]'], ['microspore mother cells [organ]'], ['microspore stage [cell type]'], ['orderly microspore exine structure [phenotype]'], ['larch microspore nucleus [organ]'], ['unicellular microspore [organ]'], ['microgametophyte (pollen) [organ]'], ['Microsporocytes [tissue]'], ['wild-type microsporocytes [organism]'], ['**Microspores and pollen grains [cell type]**', 'microspores/pollen [cell type]'], ['unitegmic micropyles [organ]'], ['tomato primary microsporocytes [cell type]'], ['one to eight microspores [cell type]']]}
# -------------------
# {'122687': [['**putative orthologs [gene]**', 'potential orthologues [gene]', 'possible orthologues [gene]', 'putative ortholog gene(s) [gene]'], ['two putative orthologs [gene]']]}
# -------------------
# {'165162': [['**internalized cargo [metabolite]**', 'endocytosed material [metabolite]', 'Internalized cargoes [metabolite]'], ['**Internalization of endocytic tracer FM4-64 [metabolite]**', 'internalisation of an endocytic tracer dye [metabolite]'], ['endocytosis of transferrin [metabolite]'], ['cellular uptake of 14 chemicals [metabolite]']]}
# -------------------
# {'46224': [['1O2-stressed fc2 seedlings [mutant]'], ['lac12 mutant seedlings [mutant]'], ['pap1-D/fls1ko seedlings [mutant]'], ['drb2/Cd seedlings [mutant]'], ['drb1/Cd seedlings [mutant]'], ['tt4 seedlings [mutant]'], ['flg22 in DD seedlings pretreated with DEX [mutant]'], ['fructose in fins1 seedlings [mutant]'], ['fructose insensitivity of fins1 seedlings [mutant]'], ['pap1 seedlings [mutant]'], ['pap1-D seedlings [mutant]'], ['dfc seedlings [mutant]'], ['stressed fc2 seedlings [mutant]'], ['stressed fc2 mutant seedlings [mutant]'], ['flavonoid-deficient tt4 seedlings [mutant]'], ['tt4(2YY6) seedlings [mutant]'], ['vte1 seedlings [mutant]']]}
# -------------------
# {'140180': [['**heat response transcripts [gene]**', 'mRNAs of some heat-inducible gene(s) [gene]']]}
# -------------------
# {'28964': [['CMT orientation [cellular process]'], ['**CMT/CMF mechanism [cell structure]**', 'CMF/CMT-based mechanism [cell structure]'], ['CMT interactions [cell type]'], ['interactions between endomembrane systems and CMTs [subcellular compartment]'], ['main factors linking CMTs and cell wall [subcellular compartment]'], ['interacting factor between CSCs and CMTs [subcellular compartment]'], ['effect of cellulose microfibrils on MT array alignment at the plasma membrane [process]'], ['cellulose synthase machinery and cortical MTs [process]'], ['generating a parallel arrangement of CMTs [protein complex]'], ['mechanisms critical for generating transverse CMT arrays in WT [protein complex]'], ['**CMT-mediated orientation of cellulose microfibrils [subcellular compartment]**', 'CMT-guided cellulose synthesis [subcellular compartment]', 'cortical microtubule (CMT)-mediated orientation of cellulose microfibrils [subcellular compartment]'], ['encountering sharp cell edges [process]'], ['interaction of CSCs with microtubules [process]']]}
# -------------------
# {'74528': [['LORELEI [protein]'], ['LORELEI-like [protein]'], ['CLE41/44 [protein]'], ['JR1 protein(s) [protein]'], ['LOC112798274 14-3-3-like protein(s) A [protein]'], ['OSJ_11117 [protein]'], ['small, secreted cysteine-rich ligands [protein]'], ['twelve grapevine protein(s) [protein]']]}
# -------------------
# {'121083': [['Continuous editing [phenotype]'], ['gene(s) editing [phenotype]', '**Genome Editing [phenotype]**', 'Genome-editing [phenotype]'], ['anticipated base editing [phenotype]'], ['genome editing target gene(s) [phenotype]'], ['editing those gene(s) [phenotype]'], ['genome editing experiments [phenotype]'], ['**gene-editing events [phenotype]**', 'different editing events [phenotype]'], ['editing outcomes [phenotype]', '**genome editing outcomes [phenotype]**', 'genome edits [phenotype]'], ['gene(s) editing activities [phenotype]', '**gene-editing activity [phenotype]**'], ['more sophisticated genome engineering [phenotype]'], ['gene(s) edited progeny [phenotype]'], ['gene(s) editing in germline tissues [phenotype]'], ['**successful gene(s) editing [phenotype]**', 'effective genome editing [phenotype]'], ['genome editing function [phenotype]'], ['endogenous gene(s) editing [phenotype]'], ['effective gene(s) modification [phenotype]'], ['the field of genome editing [phenotype]'], ['precise gene-editing tool [phenotype]'], ['genotype-independent gene(s) editing [process]'], ['marker gene-independent genome engineering [phenotype]'], ['identifying delivery-mediated gene(s) editing [phenotype]'], ['genome-editing purposes [phenotype]'], ['genome editing research [phenotype]'], ['efficient genome engineering [phenotype]']]}
# -------------------
# {'59649': [['cell junction (GO:0030054) [cell type]'], ['the wall in fibre cells [cell type]'], ['defects in cortical microtubule organization in fiber cells [cell type]']]}
# -------------------
# {'81737': [['native ScHal3 [protein]'], ['native Hal3 [protein]'], ['Wildtype RACB [protein]'], ['wild-type AS2D protein(s) [gene]'], ['TMEM16A wild-type protein(s) [protein]'], ['wt coilin [protein]'], ['wild-type GUS protein(s) [protein]'], ['wild-type P3 protein(s) [gene]'], ['**wt HcPro [protein]**', 'Wild-type (wt) HcPro [protein]'], ['wild-type OsPP2C50 [protein]'], ['Native Sco protein(s) [protein]'], ['wild-type Ngb [protein]'], ['wild-type CrUb [protein]'], ['unmodified and modified forms of HTA9 [protein]'], ['original SEU protein(s) [protein]'], ['wild-type CHLM [protein]'], ['wt MP [protein]'], ['wild-type SR protein(s) [protein]']]}
# -------------------
# {'88515': [['split root(s) agar plate assays [treatment]'], ['s1 seeds [treatment]'], ['both systems [treatment]'], ['colonization assays [treatment]'], ['surface of a 45° inclined agar plate [treatment]'], ['surface of a horizontal impenetrable plate [treatment]'], ['split agar plates [environment]'], ['early germination tests on the ground [treatment]'], ['bottom of Petri dish [treatment]'], ['lines with smaller diameters [treatment]'], ['plane pl1 [treatment]'], ['plane pl2 [treatment]'], ['miniaturized agar and soil system [treatment]'], ['seedlings and assay buffer [treatment]'], ['beds of glass spheres [treatment]'], ['soil to compare root(s) architecture in Pi-limiting soil conditions with that observed on agar plates [treatment]'], ['agar plates containing NaCl [treatment]'], ['plated on agar plates containing test compounds [treatment]']]}
# -------------------
# {'167266': [['AS derivatives [metabolite]'], ['endogenous TAA [metabolite]'], ['feeding of L-sorbosone [metabolite]'], ['metabolites such as ascorbic acid [metabolite]', 'Plant-derived ascorbate [metabolite]', '**endogenous ascorbic acid [metabolite]**'], ['production of ascorbate [metabolite]', 'synthesis of Asc [metabolite]', '**synthesis of ascorbic acid [metabolite]**'], ['metabolites of ascorbate synthesis [metabolite]'], ['production of L-ascorbic acid [metabolite]'], ['production of dehydroascorbate [metabolite]'], ['AsA precursor [metabolite]'], ['minor sugars involved in ascorbate synthesis [metabolite]'], ['tuber ascorbate [metabolite]']]}
# -------------------
# {'42251': [['PDR11 [mutant]'], ['plant(s) depleted of PDAT1 [mutant]'], ['atdrp1a single mutants [mutant]'], ['atdrp2b single mutants [mutant]'], ['atdrp1e null mutant plant(s) [mutant]'], ['NRPD1 position mutated in A. thaliana nrpd1-47 [gene]']]}
# -------------------
# {'19963': [['enhanced resistance to BXW disease [phenotype]'], ['enhanced resistance to tomato bacterial speck [phenotype]'], ['enhanced disease resistance to bacterial leaf streak (BLS) [phenotype]'], ['enhanced disease resistance to bacterial blight (BB) [phenotype]'], ['increased late blight resistance [phenotype]', 'greater resistance to late blight [phenotype]', '**enhanced resistance to late blight [phenotype]**', 'increased resistance to late blight [phenotype]', 'reduced susceptibility to late blight [phenotype]', 'enhanced late blight resistance [phenotype]'], ['enhanced blast disease-resistance [phenotype]'], ['**enhanced bolting resistance [phenotype]**', 'improved bolting resistance [phenotype]'], ['enhanced clubroot resistance [phenotype]'], ['increased resistance to citrus canker [phenotype]', '**enhanced citrus canker resistance [phenotype]**'], ['enhanced resistance to seedling blight [phenotype]'], ['increased tolerance to blast disease [phenotype]'], ['increased bacterial wilt (BW) tolerance [phenotype]'], ['increased resistance to bacterial wilt [phenotype]', 'significant levels of enhanced resistance to bacterial wilt (BW) [phenotype]', '**enhanced resistance to bacterial wilt (BW) [phenotype]**']]}
# -------------------
# {'138189': [['Constitutive expression of Class I KNOX gene(s) [gene]'], ['constitutive high level expression of CLV3 [gene]'], ['constitutive expression of CRK6 [gene]'], ['constitutive expression of CRK10 [gene]'], ['constitutive expression of CRK11 [gene]'], ['constitutive activation of LjCLE gene(s) [gene]'], ['Constitutive expression of AtTSPO [gene]'], ['Constitutive expression of MpKAN [gene]'], ['Constitutive expression of KNOX2 [gene]'], ['constitutive expression of SlIPT3 [gene]'], ['Constitutive expression of CaPUB1 [gene]'], ['constitutive expression of CnTCP4 [gene]'], ['constitutive expression of CnTCP2 [gene]'], ['Constitutive expression of CKX1 [gene]'], ['Constitutive expression of NLRs [protein]'], ['Constitutive expression in leaf of SKS13 [gene]'], ['constitutive expression of CRF2 [gene]'], ['Steady state levels of C4 protein(s) [gene]'], ['CRL constitutive expression [phenotype]'], ['Constitutive expression of FCP1 [gene]'], ['constitutive expression of mcSKD1 [gene]'], ['Constitutive expression of CIR1 [gene]'], ['constitutive expression of AdCIPK5 [gene]'], ['the stability of Keep on Going (KEG) [gene]'], ['constitutive expression of RAP2.12 [gene]'], ['Rhythmical expression of CO [phenotype]'], ['CO diurnal expression [process]']]}
# -------------------
# {'73713': [['ROC1 [protein]'], ['ROS sensors [protein]'], ['aCO2 [protein]'], ['plant(s) RSHs [protein]'], ['OXS2 [protein]'], ['oxi1 [protein]'], ['PER1 protein(s) [protein]'], ['TOP1 and TOP2 [protein]'], ['osmotin-like (Ol) [protein]'], ['CPR [phenotype]'], ['SAPX [protein]'], ['ERFVII8 [protein]'], ['Ripening-induced protein(s) (ASR) [protein]'], ['**OSIP108 [protein]**', 'oxidative stress-induced bioreactive peptide, OSIP108 [protein]'], ['ROS [protein]'], ['OC-I-inhibited cysteine proteinases [protein]'], ['The PPR-Domain protein(s) SOAR1 [protein]'], ['A novel protein, OZONE-RESPONSIVE APOPLASTIC PROTEIN1 (OsORAP1) [protein]', '**OsORAP1 [protein]**'], ['plant(s) ZCr [protein]'], ['stromal-cell-derived factor 2-like protein(s) [protein]'], ['hydrogen peroxide-responsive protein(s) [protein]'], ['Enhanced stability of ARR10 protein(s) [gene]'], ['SIMILAR TO RCD-ONE (SROs) [protein]'], ['CaOSM1 protein(s) [protein]'], ['Stromal cell-derived factor2 (SDF2)-type protein(s) [protein]'], ['ROS-related protein(s) [protein]'], ['JAZ stability [protein]'], ['oxidation-related zinc finger one protein(s) [protein]'], ['ROS response protein(s) in root(s) [protein]'], ['ROS-associated protein(s) [protein]'], ['aging responsive protein(s) [phenotype]'], ['oxidant-sensitive protein(s) in plant(s) [organism]'], ['oxidant receptor protein(s) 1 (Orp1) [protein]'], ['bZIP60, both isoforms of IRE1, S2P, NAC062, J-domain protein(s) ERdj2a, and AERO1 (ER oxidoreductin 1) [protein]'], ['POX2 [protein]'], ['ROS-responsive protein(s) [protein]'], ['stability of RAP2.12 [protein]'], ['groups including pathogenesis-related proteins, metallothioneins, severe drought-stressed proteins, Hsp90, thaumatin-like protein, catalase (CAT1), WRKY family, and oxalate oxidase [phenotype]'], ['Cys-rich repeat secretory protein(s) 55 precursor [protein]'], ['ARR5 stability [phenotype]']]}
# -------------------
# {'126982': [["absence of 5' UTR [regulatory sequence]"], ['lack of Pol IV [gene]', '**Loss of Pol IV [gene]**'], ['loss of DRB2 activity [gene]'], ['absence of natural TE insertions in RPI2 [gene]'], ['Lack of pol IV RNAs [gene]'], ['Loss of maternal Pol IV [gene]'], ['Loss of RNA Pol IV [gene]'], ["Loss of one parent's Pol IV [gene]"], ['**Loss of XRN4 [gene]**', 'loss of XRN4 activity [gene]'], ['absence of HEXO3-RNAi [gene]'], ['absence of MORF protein(s) [gene]'], ['absence of AtNUC-L1 protein(s) [gene]'], ['absence of DRB1 activity [gene]'], ['loss of RDR2 [gene]'], ['loss of ELP6 [gene]'], ['lack of DCL2 [gene]'], ['lack of DCL3 [gene]'], ['absence of Cas13 [gene]'], ['absence of RDRs [gene]'], ['deletion of yeast nuclear RNase P RNA [gene]'], ['lack of asymmetric distribution of PIN3 [gene]'], ['lack of phasing for NBS-LRR-derived siRNAs [rna]'], ['The absence of stem(s) loops #1 and #2 [subcellular compartment]'], ['absence of a functional MRE [subcellular compartment]'], ['loss of Pol V [protein]'], ['lack of Shine-Dalgarno sequence [genetic element]'], ['absence of functional Pol IV [treatment]'], ['absence of respective uORF [gene element]'], ['absence of RNA triggers [epigenotype]'], ['D-arm absent from tRNA-like structure [genetic feature]']]}
# -------------------
# {'121395': [['repeats [phenotype]'], ['a variable number of tandem repeats [phenotype]'], ['variant repeat tracts [phenotype]'], ['Highly divergent tandem repeats [phenotype]']]}
# -------------------
# {'138084': [['GL2 expression [phenotype]'], ['**IKU2 expression [gene]**', 'expression of IKU2 [gene]'], ['KAT2 expression [gene expression]'], ['CTPS2 expression [gene]'], ['**FC2 expression [gene]**', 'Expression of FC2 [gene]'], ['FC2 expression [gene expression]'], ['ASIL2 expression [gene]'], ['ETR2 expression [phenotype]'], ['Expression levels of EIN2 [gene]'], ['DLK2 gene(s) expression [gene]'], ['**ACT2 expression [gene]**', 'ACT2 gene(s) expression [gene]'], ['expression of JAZ2 [gene]'], ['Expression levels of GTG2 [gene]'], ['Expression levels of DREB2A [gene]'], ['Expression of VOZ2 [gene]'], ['GAS2 expression [gene]'], ['Expression of 2-ODD [gene]'], ['endogenous levels of TCMP-2 [gene]'], ['ZmAPR2 expression [gene]'], ['IREG2 expression [gene]'], ['TEM2 levels [gene]'], ['GL2 activity [phenotype]'], ['**GL2 expression [gene]**', 'expression levels of GL2 [gene]'], ['Expression of RTM2 [gene]'], ['TOE1/2 levels [gene]'], ['GSTF2 expression [gene]'], ['**GR2 protein(s) levels [gene expression]**', 'GR2 protein(s) level [gene expression]'], ['MtDCL2b expression [gene]'], ['TGG2 expression [gene expression]'], ['OPT3 expression [gene expression]'], ['Expression of MAX2 [gene]'], ['**GDEF2 expression [gene]**', 'Expression of GDEF2 [gene]'], ['Vlaro2 expression [gene]'], ['abundance of Tim23-2 [gene]'], ['comparable level of Thi2.1 expression [phenotype]'], ['NDB2 expression [gene]'], ['GSH2 expression [phenotype]'], ['expression of endogenous MAF2 gene(s) [gene]'], ['expression of its paralogues [gene]'], ['full ECT2 function [gene]'], ['TCU2 expression [gene expression]'], ['progression of TT2 expression [gene expression]'], ['endogenous LOG2 gene(s) activity [gene]'], ['LOG2 expression [gene]'], ['TaTIP2;2 expression [gene expression]'], ['accumulation of Thi2.4 protein(s) [gene]'], ['Ivr2 expression [gene]'], ['AtZIP2 expression [gene]'], ['TED2 expression [gene]'], ['ECT2-FLAG-ADAR expression levels [gene]'], ['Dof2.1 expression [gene]'], ['basal expression levels of KIN2 [gene]'], ['ADC2 expression [gene expression]'], ['expression of ACTIN2 [gene]']]}
# -------------------
# {'66209': [['FH1 protein(s) [protein complex]'], ['FH EXTs [protein]'], ['FH EXTs [gene]'], ['dis2-1S protein(s) [protein]'], ['Actin-associated formin family protein(s) [gene]'], ['FtsZ homologues [gene]'], ['Profilin families [protein family]'], ['metazoan formins [gene]'], ['Class II formins [gene]'], ['expression of profilin gene(s) (PRF4 and PRF5) [gene]'], ['ADF/cofilin (AC) family [protein family]'], ['flagellar basal-body rod modification protein(s) FlgD [protein]'], ['PRF1 and PRF2 protein(s) [protein]'], ['Class I formin FH1 [gene]'], ['actin-binding formin homology FH2 protein(s) [protein]'], ['numerous group 2 formins [gene]'], ['Cdc12p formin [gene]'], ['AtACT2-containing filaments [protein]'], ['general properties of the formin family [gene]']]}
# -------------------
# {'109497': [['single A [genetic element]'], ["DUE's [genetic element]"], ['mini3a [genetic element]'], ['helitron 11 [genetic element]'], ['A+C (Imino, M) [genetic element]'], ['all purine progenote [genetic element]'], ['all pyrimidine progenote [genetic element]'], ['C-C pair [genetic element]'], ['only one of eight pairs [genetic element]'], ['binary elements [component]']]}
# -------------------
# {'24': [['**pollen functions [phenotype]**', 'pollen grain function [phenotype]'], ['pollen feature [phenotype]'], ['pollen nutrition [phenotype]'], ['pollen phenotypes [phenotype]'], ['pollen physiology [phenotype]'], ['normal pollen function [phenotype]'], ['phosphor in seeds and pollen grains [phenotype]']]}
# -------------------
# {'51350': [['panicle characteristics similar to EMS-induced frizzy panicle mutant fzp [mutant]'], ['panicle characteristics similar to gamma-ray induced frizzy panicle mutant fzp2 [mutant]']]}
# -------------------
# {'44730': [['cesa5-2 fei2-3 double mutant [mutant]'], ['**cesa5 fei2 double mutant [mutant]**', 'fei2 cesa5 double mutant [mutant]'], ['hy5 csu2 double mutants [mutant]'], ['seuss cyp85A2 double mutants [mutant]'], ['seu-3 cyp85A2-1 double mutant [mutant]'], ['seu-3 cyp85A2-2 double mutant [mutant]'], ['seu-1 cyp85A2-4 double mutant [mutant]'], ['sco3-1phyB-9 [mutant]'], ['swn7clf28 double mutant [mutant]'], ['flu/ex1 double mutant [mutant]']]}
# -------------------
# {'125145': [['msh1 rearrangements [genomic feature]'], ['abrupt changes in coverage of the At7 genome [gene]'], ['increase in CG content [genetic feature]'], ['aCGH-detected mutation [mutation]'], ['one-rearrangement reads [phenotype]'], ['Chr4 alterations [genotype]'], ['Chr5 alterations [genotype]'], ['shift in base composition [genetic feature]'], ['sequence anomalies [gene]'], ['suggesting presence of genomic rearrangement [gene]'], ['identification of complex changes [process]'], ['changes in primary sequence [genomic feature]'], ['aCGH identified mutation [phenotype]'], ['indicate rearrangement [mutant]'], ['5-3 copy number change [phenotype]']]}
# -------------------
# {'83273': [['circular dichroism [phenotype]'], ['solvable crystal structure [phenotype]'], ['outcome of crystallization trial [phenotype]'], ['crystallization of the protein(s) [phenotype]'], ['quality of protein(s) crystals [phenotype]'], ['**resolution for computing atomic structures [phenotype]**', 'resolutions up to 1.45 A [phenotype]'], ['resolution of the gels [phenotype]']]}
# -------------------
# {'31266': [['ethylene-mediated cell expansion of the epidermis [phenotype]'], ['Epidermal growth factor [signal molecule]'], ['ER-regulated cell elongation in hypocotyl [phenotype]'], ['many growth and cell fate decisions [process]']]}
# -------------------
# {'149512': [['SEGS-1 sequences [gene]'], ['SEGS-1 related sequences [gene]'], ['full-length copy of SEGS-1 [gene]'], ['SEGS-2 episomes [gene]', '**SEGS-2 episome [gene]**'], ['SEGS-2 partial copies [gene]'], ['SEGS-2-related sequences [gene]'], ['Sequences Enhancing Geminivirus Symptoms (SEGS1 and SEGS2) [gene]'], ['SEGS-1 related sequences [genetic material]'], ['SEGS-1 sequence [genetic material]'], ['SEGS-1 and SEGS-2 [genetic material]']]}
# -------------------
# {'19384': [['Acclimation efficiency [phenotype]'], ['metabolic flexibility [phenotype]'], ['Aphid fitness [phenotype]'], ['fitness of plant(s) [organism]'], ['survival of DPF plant(s) [phenotype]'], ['intraspecific recognition [phenotype]'], ['interspecific recognition [phenotype]'], ['ability of plant(s) to forage their environment [phenotype]'], ['intrinsic metabolic fitness [phenotype]'], ['host-plant productivity [phenotype]'], ['**key factors for high acclimation capacity [phenotype]**', 'key determinant for optimal acclimation capacity [phenotype]'], ['environmental performance [phenotype]'], ['epiphytic fitness [phenotype]'], ['leaf adapted obligate biotroph [phenotype]'], ['**competitive ability of plant(s) [phenotype]**', 'competitive power of plant(s) [phenotype]'], ['host fitness [phenomenon]'], ['environmental fitness of plant(s) [process]']]}
# -------------------
# {'138656': [['expression levels of AtFRO2 [gene]', '**expression of AtFRO2 [gene]**'], ['AtFer1 expression [gene]'], ['ASMT expression [gene]'], ['AtFIT expression [gene]'], ['expression of At-NEET [gene]', '**At-NEET expression [gene]**'], ['expression of AtIRT2 [gene]'], ['**expression of IRON-REGULATED TRANSPORTER1 (IRT1) [gene]**', 'did not influence the expression of AtIRT1 [gene]', 'expression of Fe-uptake-associated gene(s) IRT1 [gene]'], ['IRT1 [phenotype]'], ['AtSHMT4 expression [gene expression]'], ['expression of AtNRAMP3 [gene]'], ['AtNRAMP3 expression [gene expression]']]}
# -------------------
# {'20901': [['5.8% of WT [organism]'], ['AF>0.2 in WT samples [phenotype]'], ['10% in WT (WT) [phenotype]'], ['50% of WT [phenotype]'], ['>10% WT [phenotype]'], ['50-60% of WT levels [phenotype]'], ['20% of the WT expression [phenotype]'], ['grain weight 51.5% and 55.2% of WT [phenotype]'], ['three to five times the nodules of WT [phenotype]'], ['50% sterol level of WT [phenotype]'], ['55% of the wild-type value [phenotype]']]}
# -------------------
# {'160258': [['Promoters of homologous FMI gene(s) [gene]', '**promoters of the floral meristem identity gene(s) [gene]**'], ['**promoters of floral meristem identity gene(s) SQUAMOSA [gene]**', 'floral meristem identity gene(s) SQUAMOSA promoter [gene]'], ['conserved motif in the promoter region of the floral meristem identity gene(s) SQUAMOSA [gene]']]}
# -------------------
# {'156790': [['GNOM-like 1 [gene]'], ['ANAC017 homologs [gene]'], ['NSP1 gene(s) [gene]'], ['plant(s) SNF1 [gene]'], ['plant(s) synaptotagmins (SYTs) [gene]'], ['plant(s) GSK3s [gene]'], ['CNI-1 gene(s) [gene]'], ['SORTING NEXIN2 (SNX2a) [gene]'], ['Sgn3 [protein]'], ['Functions of Acorus sequences [gene]'], ['plant(s) Rac-like GTPases [gene]'], ['CARD1 homologues [gene]'], ['**synaptotagmin 1 [gene]**', 'synaptotagmin 1 (SYT1) [gene]'], ['combinations of transporters, receptors, and kinases [gene]'], ['flg22-induced phosphorylation of PBL1 [phenotype]'], ['GNOM pathway [gene]'], ['CORYNE function [gene]'], ['AtNIGT1/HRS1 motif [gene]'], ['signal from SGN3 [gene]'], ['snc1 signaling [gene]'], ['signaling mediated by AGCVIII protein(s) kinase UCN [gene]'], ['NODULE INCEPTION (NIN)-LIKE protein(s) (NLP) gene(s) family [gene]']]}
# -------------------
# {'19225': [['CRR1-dependent Cu accumulation [phenotype]'], ['High concentrations of Zinc [trait]'], ['Zn accumulation capacity [phenotype]'], ['variation in Zn accumulation capacity [phenotype]'], ['highest Zn accumulation capacity [phenotype]'], ['altered Zn accumulation capacity [phenotype]'], ['**Zn accumulation [phenotype]**', 'accumulation of Zn [phenotype]', 'Zn accumulation phenotype [phenotype]', 'plant(s) zinc accumulation [phenotype]', 'zinc (Zn) accumulation [phenotype]'], ['**high Zn accumulation [phenotype]**', 'higher accumulation of Zn [phenotype]', 'relatively high Zn accumulation [phenotype]', 'Increased Zn accumulation [phenotype]', 'higher Zn accumulation [phenotype]'], ['increased Zn concentrations [phenotype]'], ['**shoot Zn accumulation [phenotype]**', 'accumulation of Zn in shoots [phenotype]', 'enhanced shoot accumulation of Zn [phenotype]'], ['increased Zn accumulation in rosette leaf and root(s) [phenotype]'], ['increased Zn accumulation in plant(s) tissues [phenotype]'], ['high Zn accumulation ability in leaf [phenotype]'], ['significant increase in plant(s) Zn accumulation [phenotype]'], ['proportional increases in Zn accumulation with increasing Zn concentrations [phenotype]'], ['strong enrichment effect on Zn [phenotype]'], ['zinc accumulation levels [phenotype]'], ['Zn tolerance and accumulation [phenotype]'], ['**storage of excess Zn [phenotype]**', 'significant impact on Zn storage [phenotype]', 'zinc deposition [phenotype]'], ['**Zn/Fe storage [phenotype]**', 'Fe/Zn storage [phenotype]'], ['higher Zn, Cd, and Ni accumulation [phenotype]'], ['Zn and Cd accumulation [phenotype]'], ['quantitative trait loci (QTL) for Zn accumulation [genetic locu]'], ['zinc accumulation quantitative trait locus [phenotype]'], ['**Zn sequestration [phenotype]**', 'vacuolar immobilization of Zn [phenotype]', 'sequestration of Zn [phenotype]', 'enhanced Zn compartmentalization in the vacuole [phenotype]', 'ability to accumulate Zn in the vacuole [phenotype]']]}
# -------------------
# {'155284': [['U2AF65A transcripts [gene]'], ['UFO RNA [gene]']]}
# -------------------
# {'97357': [['**outer layers of seed coat [organ]**', 'shell of plant(s) seed [organ]', 'outermost layer of the seed [organ]', 'outer layer of seed coat [organ]', 'surface of seeds [organ]', 'covering structures [organ]', 'stiff envelope [organ]', 'outermost layers of seeds [organ]', 'extremely reduced seed epidermis [organ]', 'outer layers [organ]', 'outer seed coat wall [organ]', 'testa of seeds [organ]', 'hard, impermeable seed coat [organ]', 'outer seed coat layers [organ]', 'outer layer of the seed coat [organ]', 'entire seed surface [organ]', 'structure of seed surface [organ]', 'seed surface structure [organ]', 'outer wall of the seed coat [organ]'], ['outer integument of seeds [organ]', 'outer seed integument [organ]', 'outer integuments of the seed coat [organ]', '**outer integument of the seed coat [organ]**', 'outer integument of seedcoat [organ]', 'external integument [organ]'], ['**inner integument of seed coat [organ]**', 'inner integument of the black seed coat [organ]', 'internal integument [organ]'], ['shorter outer integument [organ]'], ['longer outer integument [organ]'], ['longer inner integument [organ]'], ['kernel aleurone [organ]'], ['seed cutin [organ]'], ['seed integument [organ]'], ['inner part of seed coat [organism]']]}
# -------------------
# {'34328': [['**Xenopus oocytes [cell type]**', 'Xenopus laevis oocytes [cell type]', 'X. laevis oocytes [cell type]', 'Xenopus laevis (African clawed frog) oocytes [cell type]', 'Xenopus oocyte cells [cell type]'], ['frog spermatozoa [cell type]'], ['water-injected control oocytes [cell type]'], ['EcHKT-expressing oocytes [cell type]'], ['HKT1 expressing oocytes [cell type]'], ['Oocytes [metabolite]'], ['AIT3/NPF4.1-expressing oocytes [cell type]'], ['NPF2.5 injected oocytes [cell type]'], ['detectable egg cell [cell type]'], ['Oocyte [organism]'], ['Xenopus leaf oocytes [cell type]'], ['isolated egg cells [cell type]']]}
# -------------------
# {'67751': [['PERKs [protein clas]'], ['**PERKs [protein]**', 'Proline rich extensin like receptor kinases (PERKs) [protein]', 'proline-rich, extensin-like receptor kinases (PERKs) [protein]'], ['PROLINE-RICH RECEPTOR-LIKE protein(s) KINASE 4 (PERK4) [gene]'], ['proline rich extension-like receptor kinases (PERKs) [gene]'], ['ERK element [phenotype]'], ['PERK protein(s) family [protein family]'], ['pERK species [protein]'], ['proline-rich extensin-like receptor kinase (PERK) family [gene family]']]}
# -------------------
# {'69128': [['Residues 35 and 36 on the central alpha-helix [protein motif]'], ['Residues 91 and 111 on the beta-sheet [protein motif]'], ['His-318, Thr-323, and Arg-566 [amino acid]'], ['catalytic triad of MtAIH [protein structure]'], ['Arg116, Ser166, and Ser167 [protein fragment]'], ['Gly376 and Ser243 [tissue]'], ['Phe148/Leu135 [amino acid]'], ['Binding of Cs<sup>+</sup> to 749th residue of AtBE1 [gene]'], ['residues His-216 and Tyr-212 [protein complex]'], ['Modifications of residues AtcTPI-Cys218 [gene]'], ['residues Phe166, Tyr169, Phe170, His276, and Phe277 [amino acid]'], ['AtCXE20 catalytic triad [protein complex]'], ['residues F366, N415, Y418 [amino acid]'], ['51 residues [protein structure]'], ['D351 and E577 [protein]'], ['apex of nucleophile elbow [organ]'], ['catalytic triad of soluble Type II thioesterases [protein]'], ['R340, D336, and D503 [amino acid residue]'], ['catalytic triad residues [gene]']]}
# -------------------
# {'14381': [['**Shortened anther filament [phenotype]**', 'filament elongation defect [phenotype]', 'short filament [phenotype]', 'shorter filament length in anthers [phenotype]'], ['elongated weak hypocotyls [phenotype]'], ['severe cracking in flowering stem(s) [phenotype]'], ['lodging stem(s) [phenotype]'], ['SCW defects in inflorescence fiber cells [phenotype]'], ['**shortened and downward-pointing pedicels [phenotype]**', 'occasional downward bending at the distal pedicel [phenotype]'], ['**fragile or brittle apex phenotype [phenotype]**', 'investigating brittle apex phenotype [phenotype]'], ['tip rupturing of moss protonemal filaments [phenotype]'], ['dwarfed, largely sterile, premature leaf senescence, and novel filamentous structures at the base of the flower [phenotype]'], ['lack of sturdiness in inflorescence stem(s) [phenotype]', '**limp floral stem(s) [phenotype]**'], ['extremely short suspensors [phenotype]'], ['**weak stem(s) [phenotype]**', 'loss of stem(s) rigidity [phenotype]', 'stem(s) weakness [phenotype]'], ['cracks in the stem(s) [phenotype]'], ['brittle stem(s) [phenotype]'], ['brittle stem(s) nodes [phenotype]'], ['collapsed interfascicular fibers [phenotype]'], ['short and occasionally fasciated stem(s) [phenotype]'], ['fragile culms [phenotype]']]}
# -------------------
# {'149825': [['A9 [protein]'], ['WT HAP1 gene(s) [gene]'], ['AtVIT1 gene(s) [gene]'], ['NPGR2 [protein]'], ['At5g11420-encoded protein(s) [protein]'], ['HaSSA protein(s) [protein]'], ['HAIKU1 [protein]'], ['TT8 protein(s) [gene]'], ['NtAn1b protein(s) [protein]'], ['Y-type TUA6 [gene]'], ['Y-type TUA8 [gene]'], ['Maternal allele of TTG1 [gene]'], ['At1g10310 transcript [gene]'], ['TaAFP-B protein(s) [phenotype]'], ['Triticum aestivum RGP (TaRGP) [protein]'], ['T1170 [transcript]'], ['AtEm1 mRNAs [gene]'], ['timothy grass profilin [gene]']]}
# -------------------
# {'151611': [['OsWAK [gene]'], ['OsWAK14 [gene]'], ['OsWAK91 [gene]'], ['OsWAK1 [gene]'], ['**OsWAK90 [gene]**', 'OsWAK90 gene(s) [gene]'], ['OsWAK112d gene(s) [gene]'], ['OsWAF1 [gene]'], ['OsWAK/Xa4 [gene]'], ['OsWAK112 [gene]'], ['OsWAK14, OsWAK91, OsWAK92, and OsWAK112 [gene]'], ['125 OsWAK gene(s) family members [gene]'], ['OsWAK gene(s) family [gene]'], ['OsiWAK1 [gene]'], ['OsWNK [gene family]'], ['OsWAK91 in rice [gene]'], ['rice WAKs [gene]'], ['OsWAK112 activity [phenotype]'], ['OsWAK gene(s) family expansion [gene]'], ['OsWAK gene(s) in indica and japonica subspecies [gene]']]}
# -------------------
# {'10291': [['Extensive cell expansion [phenotype]'], ['**enhanced post-mitotic cell expansion [phenotype]**', 'induction of enhanced post-mitotic cell expansion [phenotype]'], ['minor cell expansion [phenotype]'], ['progressive enlargement of stem(s) cell reservoirs [phenotype]'], ['Cortical cell expansion [phenotype]'], ['**post-mitotic cell expansion [phenotype]**', 'phase of post-mitotic expansion [phenotype]', 'post-mitotic cell expansion activity [phenotype]', 'postmitotic cell expansion [phenotype]'], ['excess mitotic expansion [phenotype]'], ['mitotic expansion [phenotype]'], ['**onset of cell expansion [phenotype]**', 'timing of cell expansion onset [phenotype]', 'onset of expansion [phenotype]', 'onset of the cell expansion phase [phenotype]'], ['**post-mitotic elongation [phenotype]**', 'postmitotic cell elongation [phenotype]'], ['nucleus expansion [phenotype]'], ['cell-expansion kinetics [phenotype]'], ['**Cellular expansion [phenotype]**', 'cell expansion itself [phenotype]'], ['nuclear and cellular expansion [phenotype]'], ['cell proliferation and/or cell expansion [phenotype]'], ['**expansion stage [phenotype]**', 'expansive stage [phenotype]'], ['involvement in cell expansion [phenotype]'], ['continued cell growth [phenotype]'], ['**extended cell expansion period [phenotype]**', 'periods of cell expansion [phenotype]', 'increased period of cell expansion [phenotype]'], ['earlier onset of cell expansion [phenotype]'], ['**endosperm cellular expansion [phenotype]**', 'endospermic cellular expansion [phenotype]'], ['intense and long period of cellular growth [phenotype]'], ['transition to cell expansion [phenotype]'], ['redundant roles in cell expansion [phenotype]'], ['mitotic cell plate expansion [phenotype]'], ['expansion ends [phenotype]'], ['expansion phases [phenotype]'], ['extensive post-mitotic cell growth [phenotype]'], ['increase in the rate of cell expansion [phenotype]'], ['phase of cell expansion and storage reserve accumulation [phenotype]']]}
# -------------------
# {'33542': [['**Chromatin remodeling [subcellular compartment]**', 'regulated structural transitions of chromatin [subcellular compartment]'], ['**sustained changes to chromatin structure [subcellular compartment]**', 'persistent chromatin changes [subcellular compartment]'], ['looser structure [subcellular compartment]', '**decondensation of the chromatin [subcellular compartment]**', 'local and temporal opening of chromatin [subcellular compartment]', 'formation of open chromatin structure [subcellular compartment]'], ['**stress-induced chromatin changes [subcellular compartment]**', 'stress-associated reorganized chromatin states [subcellular compartment]'], ['chromatin stability [subcellular compartment]'], ['SWI/SNF-dependent accessibility [subcellular compartment]'], ['reprogramming of accessible chromatin [subcellular compartment]'], ['minimal changes in chromatin accessibility [subcellular compartment]'], ['loss of chromatin accessibility [subcellular compartment]'], ['restriction of chromatin accessibility [subcellular compartment]'], ['stable association of cohesin with chromatin [subcellular compartment]'], ['problem of chromatin status [subcellular compartment]'], ['conserved and ubiquitous structural components of eukaryotic chromatin [subcellular compartment]'], ['structural properties of chromatin [subcellular compartment]'], ['analysing chromatin dynamics [subcellular compartment]'], ['changing allocation of chromatin states [subcellular compartment]'], ['chromatin compaction dynamics [subcellular compartment]'], ['dynamic changes of chromatin structure [subcellular compartment]'], ['sequence determinants of heterochromatin condensation [subcellular compartment]'], ['controlling chromatin compaction [subcellular compartment]'], ['context of chromatin structures [subcellular compartment]'], ['**highly condensed chromatin [subcellular compartment]**', 'highest level of chromatin compaction [subcellular compartment]'], ['access to diverse chromatin states [subcellular compartment]'], ['high chromatin stability [subcellular compartment]'], ['chromatin destabilization [subcellular compartment]']]}
# -------------------
# {'77861': [['SBP-box DNA-binding domain [protein domain]', '**SBP-domain [protein domain]**', 'SBP motif [protein domain]', 'plant-specific DNA-binding domain named SBP [protein domain]'], ['SBP domains [protein]'], ['protein(s) sequences of the DNA-binding domain of SBP-box gene(s) [gene]']]}
# -------------------
# {'54598': [['35S::SEC-overexpressing transgenic plant(s) [mutant]'], ['35S:SEPs transgenic plant(s) [mutant]']]}
# -------------------
# {'122940': [['**fast evolution of lineage-specific gene(s) [phenotype]**', 'acceleration of LS gene(s) evolution [phenotype]'], ['emergence of proto-genes [phenotype]'], ['faster evolution in young primate gene(s) [phenomenon]'], ['faster than their paralogs [process]'], ['de novo gene(s) evolution [phenomenon]'], ['maternal-offspring co-adaptation theory [phenomenon]'], ['intron gains [phenotype]']]}
# -------------------
# {'140773': [['promoters of ABCB11 [gene]'], ['promoters of ABCB14 [gene]'], ['promoters of ABCB15 [gene]'], ['promoters of ABCG33 [gene]'], ['ABC transporter gene(s) promoters [gene]'], ["epidermal ABC transporters' promoters [gene]"], ['**promoters of ABA-responsive gene(s) [gene]**', 'promoter of ABA-responsive gene(s) [gene]', 'promoters of ABA responsive gene(s) [gene]', 'promoter regions of ABA-responsive gene(s) [gene]'], ['promoters of AtBAG gene(s) [gene]'], ['Promoter regions of GI/ABA-regulated transcripts [genomic region]'], ['promoter of Ni-inducible gene(s) (AHB1) [gene]'], ['four alternative alcA promoter-driven reporter gene(s) [gene]'], ['promoters of AtABA1, AtABA3, AtNCED3, AtAAO3, and AtCYP707A3 [gene]'], ['promoters of ABA-inducible gene(s) [gene]'], ['promoters of ABA-repressed gene(s) [gene]'], ['promoters of ABA-induced gene(s) [gene]'], ['promoters of ABA-related gene(s) [gene]'], ['promoters of ABA-dependent gene(s) [gene]'], ['promoter regions of gene(s) critical for ABA biosynthesis [process]'], ['promoter regions of AHG3 [gene]'], ['promoter regions of HAB1 [gene]'], ['promoter regions of HAB2 [gene]'], ['promoter regions of ABA-related group-A PP2C-encoding gene(s) [gene]'], ['promoters of downstream gene(s) of the AREB family [promoter]'], ['promoters of ABA response gene(s) [gene]'], ['promoters of gene(s) involved in ABA signalling [phenotype]'], ['promoters of ABA-regulated gene(s) [gene]'], ['promoter of gene(s) encoding ABA anabolic enzymes [gene]'], ['promoters of ABA biosynthetic gene(s) [gene]'], ['regulatory region of ABA-induced gene(s) [gene]'], ['promoters of ABA-responsive ABF/AREB TF gene(s) [gene]'], ['promoter analyses of ABA-regulated gene(s) [gene]'], ['promoters of A-ARR gene(s) [gene]'], ['promoter regions of ABA signaling factors [dna sequence]'], ['ABA3 promoters [gene]'], ['promoters of CYP707A3 [gene]'], ['promoters of AAO3 [gene]']]}
# -------------------
# {'155550': [['HAG subfamily [gene]'], ['multiple HAC and HAG gene(s) [gene]'], ['six HATs [gene]'], ['32 HATs [gene]'], ['HAG1-HAG3 [gene]'], ['4 HAGs [gene]'], ['HPA2-like HAGs [gene]']]}
# -------------------
# ...
# -------------------
# {'19977': [['**Enhanced resistance [phenotype]**', 'higher level of resistance [phenotype]', 'stronger resistance [phenotype]', 'stronger resistance phenotype [phenotype]', 'more resistance [phenotype]', 'further increased resistance [phenotype]', 'higher plant(s) resistance [phenotype]', 'elevated level of resistance [phenotype]', 'increased resistance phenotype [phenotype]', 'increased resistance capability [phenotype]', 'more resistant plant(s) [phenotype]', 'elevated resistance [phenotype]', 'enhanced level of resistance [phenotype]'], ['long-lasting enhanced resistance [phenotype]'], ['increased systemic resistance [phenotype]'], ['stronger basal resistance [phenotype]'], ['elevated resistance during subsequent infections [phenotype]']]}
# -------------------
# {'163081': [['antimicrobial secondary metabolite accumulation [metabolite]'], ['accumulation of antimicrobial secondary metabolites [molecule]']]}
# -------------------
# {'10847': [['mitochondrial density [phenotype]'], ['**mitochondrial iron levels [phenotype]**', 'iron in mitochondria [phenotype]'], ['status of mitochondrial Fe-S cluster assembly [phenotype]'], ['oxygen carrier [phenotype]']]}
# -------------------
# {'86850': [['We have deconstructed the traditional ISH protocol [treatment]'], ['RapiGest [treatment]'], ['optimization of In-Fusion [treatment]'], ['PEA-Clarity [treatment]'], ['Rosenfeld et al. [author]'], ['Sequential processing with PNGase F [treatment]'], ['Sequential processing with legumain [enzyme]'], ['relatively high efficiency of this procedure [process]'], ['Manual removal of zona pellucida [treatment]'], ['bacterial PI-PLC treatment [process]'], ['high-throughput purified granule methods [treatment]'], ['solution-based targeted genomic enrichment methodology [treatment]'], ['tandem StrepII tags [treatment]'], ['distinct tailoring rationale [treatment]'], ['Newly developed procedure [treatment]'], ['Peptidomic analysis [treatment]'], ['Integrated approach to proteomics and peptidomics [treatment]'], ['N-glycan processing [treatment]'], ['mPEG-MAL treatment [treatment]'], ['EPG digestion [treatment]'], ['SFI [treatment]'], ['tagmented products [process]'], ['enhanced stringency [treatment]'], ['and may become the preferred method for plant(s) proteomics in the future [treatment]'], ['E3-DART system [treatment]'], ['solid-phase enzymatic reactions [treatment]'], ['multi-enzyme digestion approach [treatment]']]}
# -------------------
# {'23162': [['signal transduction cross-talk [phenotype]'], ['cross-communication [phenotype]'], ['combinatorial cross-talk [phenotype]'], ['**Cross talk [phenotype]**', 'cross-talks [phenotype]'], ['molecular cross-talk [phenotype]'], ['interactions between signaling pathways [phenotype]', 'cross talk between multiple signaling pathways [phenotype]', '**cross-talk between signalling pathways [phenotype]**', 'cross-talk of different signaling pathways [phenotype]'], ['cross-talk in plant(s) [phenotype]'], ['bidirectional cross-talk [phenotype]'], ['cross talk between temperature and H2O2 signaling [phenotype]'], ['cross-talk with other signaling molecules [phenotype]'], ['complex cross-talk [phenotype]'], ['cross-talk and signal integration [phenotype]'], ['cross talk between defense signaling pathways [phenotype]'], ['node for cross talk [phenotype]', '**cross-talk node [phenotype]**'], ['considerable cross talk [phenotype]'], ['metabolic cross-talk [phenotype]']]}
# -------------------
# {'17727': [['wavelength dependent photosystem excitation energy distribution [phenotype]', '**photosystem excitation-energy distribution [phenotype]**', 'excitation energy distribution [phenotype]'], ['excitation pressure of PSII [phenotype]', '**photosystem II excitation pressure [phenotype]**'], ['excitation trapping time [phenotype]'], ['Increase in free-energy gap [phenotype]'], ['560 nm light [phenotype]'], ['590 nm light [phenotype]'], ['relative excitation level of photosystems [phenotype]'], ['pH-dependent de-excitation of singlet excited chlorophyll molecules [phenotype]']]}
# -------------------
# {'169878': [['plant(s) DHS activities [enzyme]', '**overall activity of DHS [enzyme]**'], ['Expression levels of AthDHS2 [enzyme]'], ['plant(s) DHS activity [enzyme activity]', '**total DHS activity [enzyme activity]**'], ['XDH protein(s) levels [enzyme]'], ['carrot DHS activity [enzyme]'], ['maize shoots DHS activity [enzyme]'], ['overall DHS activity [process]']]}
# -------------------
# {'76439': [['Efh [gene feature]'], ['N-glycosylation within FAS1 domain of FLA11 [protein domain]'], ['PHD domain [phenotype]'], ['GST-fused SE Middle (SE-Mid) domain [protein]'], ['SGF11 and ENY2 amino or carboxy-terminal extra-domains [protein]'], ['GH1 domains [protein domain]'], ['GH1 domain of g34113.t1 [protein domain]'], ["Domain IV and the G' subdomain of domain I [protein complex]"], ["SPY's self-fucosylation region [protein region]"], ['presence of FH2 domain [protein domain]'], ['EF1G [domain]'], ['HA-F+Kelch peptide [gene]'], ['**GYF-domain-containing protein(s) [protein]**', 'GYF domain protein(s) [protein]', 'GYF domain-containing protein(s) [protein]'], ['GYF domains [protein domain]'], ['PF02213 [protein family]'], ['GAF domain cleft [structure]'], ['C2 part of GbMYB25 [protein]'], ['GK domains of NGK-1 [protein]'], ['crystal structure of the ENT domain of EMSY [protein domain]'], ['Crystal structures of Geph-G [protein domain]'], ['Crystal packing of the DDL FHA domain [protein domain]'], ['predicted 46 kDa amino-terminal GI domain [phenotype]'], ['binding epitope of the GYF domain from the yeast SMY2 protein(s) [protein domain]'], ['GhIQD21 [protein]'], ['N-glycosylation in the FAS1 domain [protein domain]'], ['5KXF [identifier]'], ['GroEL protein(s) domain [protein]'], ['domains III, V, and VI [protein domain]'], ['H/G domain [protein domain]'], ['single GH1 domain [protein domain]'], ['WG-1 [subdomain]'], ['TFIIB-like domain architecture [protein domain]'], ['core GGF region [protein domain]'], ['**peptides spanning a portion of the HEAT1/MIFG domain [protein domain]**', 'peptides covering the HEAT1/MIFG domain [protein domain]'], ['protein(s) with GST domains and EF1 gamma domain [protein]'], ['protein(s) with GST domains but not EF1 gamma domain [protein]'], ['EF1Bgamma domain [phenotype]'], ['trans auto-fucosylation sites [protein domain]'], ['structural constraints between Fc N-glycan and IgG1 CH2 domains [protein]'], ['GhWDR-C [protein domain]'], ['cysteine-rich, EGF-like, and three sushi domains [subcellular compartment]'], ['Thr-138 [protein domain]'], ['GYGSTQTAxxxSxLxA repeats [protein domain]'], ['TIFY and Jas domains [domain]'], ['PHD-SWIB-Plus3-GYF domain [protein domain]'], ['glutamate-rich regions [protein domain]'], ['GIY-YIG nuclease domain [protein domain]'], ['polyproline (Poly-P) of formin AtFH1 [protein region]']]}
# -------------------
# {'172634': [['**OPP pathway [gene]**', 'the oxidative pentose phosphate (OPP) pathway [gene]'], ['Oxidative pentose phosphoric pathway (OPPP) [process]', 'OPPP [process]', 'Oxidative pentose phosphate (OPP) [process]', '**OPP pathway [process]**', 'oxidative pentose phosphate pathway (OPPP) [process]', 'OPPP pathway [process]', 'OPP [process]'], ['OPPP [metabolic pathway]', '**OPP pathway [metabolic pathway]**'], ['OPPP flux [pathway]'], ['OPPP [pathway]'], ['cytosolic OPPP flux [process]'], ['cytosolic OPPP [process]'], ['OPP pathway [phenotype]'], ['OPPP activation [process]'], ['OPPP pathway [metabolite]'], ['**oxidative pentose phosphate pathway (OPPP) [metabolite]**', 'oxidative pentose phosphate pathway (OPPP) [metabolite]'], ['OPP [metabolite]'], ['**oxidative part of OPPP [metabolic pathway]**', 'oxidative part of the OPPP [metabolic pathway]'], ['NADPH production by the OPPP [metabolite]'], ['incomplete oxidative pentose-phosphate pathway (OPPP) [metabolic pathway]'], ['**oxidative pentose-phosphate pathway (OPPP) [metabolic pathway]**', 'oxidative pentose phosphate pathway (OPPP) [metabolic pathway]'], ['the OPP pathway for nucleotide biosynthesis [gene]'], ['carbon skeletons from a shared resource pool in the OPP pathway [gene]'], ['carbon flow through OPPP [metabolic pathway]'], ['**first committed step of the oxidative pentose phosphate pathway (OPPP) [pathway]**', 'first committed step of the oxidative pentose-phosphate pathway (OPPP) [pathway]'], ['G6P flux through cytosolic OPPP [phenotype]'], ['accumulation of OPPP intermediates [metabolite]'], ['first OPPP step [process]'], ['NADPH-producing OPPP reactions [metabolic pathway]'], ['**third OPPP step [process]**', 'third step of the oxidative pentose-phosphate pathway (OPPP) [process]'], ['transport of OPPP metabolites [process]'], ['glycolysis and OPPP [metabolic pathway]'], ['separation of Calvin-Benson cycle from OPPP [phenotype]'], ['first step of the oxidative pentose-phosphate pathway (OPPP) [pathway]'], ['regeneration of glucose-6-P molecules in the oxidative pentose phosphate pathway [metabolic pathway]'], ['production of OPPP/glycolysis intermediates [process]'], ['OPPP in the dark [process]'], ['activation of the OPPP [metabolic pathway]'], ['OPP pathway [metabolic process]'], ['step of OPPP beyond PGL [metabolite]'], ['complete oxPPP [process]'], ['OPPP reactions [process]'], ['first step of OPPP [metabolic pathway]']]}
# -------------------
# {'109900': [['**Dof motif [gene]**', 'presence of conserved DNA binding with one finger (Dof) binding elements [gene]', 'three conserved Dof elements [gene]', 'cognate sites for Dof transcription factors [gene]', '(A/T)AAAG sequence [gene]'], ['IDD motif [gene]'], ['CBF DNA binding motif [gene]'], ['Dof-box (-341/-338) [dna sequence]', '**Dof TFBS [dna sequence]**'], ['IDEF2 motif [dna sequence]'], ['ERF115 motif [phenotype]'], ['Dof factor binding motifs [phenotype]'], ['Dof-binding consensus sequences in their promoter regions [protein]'], ['CORE sites [gene region]'], ['MEF2-type [dna motif]'], ['Dof-binding motifs [dna motif]'], ['AAAG sequence [sequence]'], ['CTTT binding site [sequence]']]}
# -------------------
# {'14502': [['**leaf color [phenotype]**', 'trait leaf color [phenotype]', 'leaf colour [phenotype]', 'leaf color phenotype [phenotype]', 'color of leaf [phenotype]', 'leaf color information [phenotype]', 'leaf color traits [phenotype]', 'color trait [phenotype]'], ['leaf colour in lettuce [phenotype]'], ['Red colour of lettuce leaf [phenotype]'], ['Red leaf [phenotype]'], ['red leaf and petioles [phenotype]'], ['light red [phenotype]'], ['light red and dark red leaf [phenotype]'], ['orange leaf [phenotype]'], ['colorful autumn foliage [phenotype]'], ['head leaf color [phenotype]']]}
# -------------------
# {'167068': [['natural product statins [metabolite]'], ['unnatural cytochalasan derivatives [metabolite]'], ['sulfoxides [metabolite]'], ['sulfated product 11 [metabolite]'], ['sulfonated natural products [metabolite]'], ['pharmaceutical formulations [metabolite]'], ['tablets [metabolite]'], ['N-hydroxylated compounds [metabolite]'], ['drug-like scaffolds [metabolite]']]}
# -------------------
# {'88886': [['30-day high altitude balloon mission [treatment]'], ['1.5 years of exposure to space vacuum [treatment]'], ['10 days on STS-9 [treatment]']]}
# -------------------
# {'65805': [['E0-4-2, E3-1-2, and E5-3-1 fragments [gene]'], ['AFP2 recruitment of TPL/HDACs [protein]'], ['activity of binding partners like HDA6 [protein]'], ['CMM2 interactions [protein interaction]'], ['FANCM direct DNA-binding cofactors [protein]'], ['two proteins, PCF1 and PCF2 [protein]'], ['protein-DNA interaction network [signaling pathway]'], ['E2F binding to RB [protein]'], ['ABF-ABRE associations [protein-gene interaction]'], ['EmBP-1 [protein]'], ['binding of CCA1 [protein]'], ['EIN3/EIL protein(s) [protein]'], ['SA-bound NPR1 dimer [protein]'], ['several portions of HBP-1a(17) [protein]'], ['LHP1 and ABAP1 [protein]'], ['DNA binding of ARF6 and ARF8 [process]'], ['ZRF1 binding to chromatin [protein]'], ['CDK8 binding [protein]'], ['interaction with ARF6 and ARF8 [protein]'], ['CRYPTOCHROME-INTERACTING BASIC-HELIX-LOOP-HELIX 1 (CIB1) [protein]'], ['bind to CmMYB6 [protein]'], ['correct binding of regulators [process]'], ['specific KNAT homeodomain protein(s) [protein]'], ['ABF3 binding [interaction]'], ["SOB3/AHL29's physical interaction with transcription factors [protein]"], ['dimerization protein(s) DPb [gene]'], ['Binding of CG-1 [protein]'], ['ABF4-AtCPK32 interaction [interaction]']]}
# -------------------
# {'7940': [['Viral diseases [phenotype]'], ['viral process [phenotype]'], ['Viruses [phenotype]'], ['how viruses tune the relationship between multiplication and virulence [phenotype]', '**link between virus multiplication and virulence [phenotype]**'], ['many other aspects of the viral lifecycle [phenotype]'], ['**virus behavior [phenotype]**', 'behaviour of viruses [phenotype]'], ['vector behaviors [phenotype]'], ['viral dynamics [phenotype]'], ['virus research [phenotype]'], ['virome [phenotype]'], ['category viral process [phenotype]'], ["viruses' activities [phenotype]", '**viral functions [phenotype]**']]}
# -------------------
# {'90345': [['plant(s) hormones and abiotic stress signals [regulatory factor]'], ['AtBI-1 function [process]'], ['Biotic and abiotic interactions [process]'], ['regulation of defense response to biotic and abiotic stresses [process]', '**response to biotic and abiotic stresses [process]**', 'induction of responses to biotic and abiotic stresses [process]', 'vital regulators in plant(s) responses to biotic and abiotic stresses [process]', 'abiotic/biotic responses [process]', 'plant(s) immunity and abiotic stress responses [process]', 'different abiotic and biotic stress responses [process]', 'mediating plant(s) response to abiotic and biotic stresses [process]', "regulation of plants' response to abiotic and biotic stresses [process]"], ['developmental and abiotic stress responses [process]'], ['mediators during biotic and abiotic stresses [function]'], ['pathogen attack and development to abiotic stresses [process]'], ['(a)biotic stress tolerance and hormone signalling [process]'], ["plant's signaling response to abiotic stresses [process]"], ['phytohormone and abiotic stresses [process]'], ['factors sensitive to biotic and abiotic stimuli [protein complex]'], ['A. thaliana responses to multiple abiotic stresses [process]'], ['both plant(s) growth and development and abiotic stress [process]'], ['important role in abiotic stresses [process]'], ['key components in response to a wide range of abiotic stresses [process]'], ['abiotic stress, light and phytohormone responses [process]']]}
# -------------------
# {'31615': [['auxin-mediated modulation of the mitotic-to-endocycle switch [phenotype]'], ['auxin-dependent inhibition of endocytosis [process]', '**auxin-regulated endocytosis [process]**', 'auxin regulation of endocytosis [process]']]}
# -------------------
# {'157227': [['GmSAUR [gene]'], ['StSAUR [gene]'], ['ZmSAUR1 (Zea mays SAURs) [gene]', '**ZmSAUR1 [gene]**'], ['SlSAUR1-like [gene]']]}
# -------------------
# {'131559': [['BtuB gene(s) [gene]'], ['BtuC gene(s) [gene]'], ['BtuN gene(s) [gene]'], ['cytochrome b(5) [gene]']]}
# -------------------
# {'99091': [["Genome sequencing of O. fragrans 'Rixianggui' (OFR) [organism]"], ["**O. fragrans 'Liuyejingui' (OFL) [organism]**", 'OFL [organism]'], ['genome-wide sequence and transcriptome of Osmanthus fragrans [organism]'], ['D. oleifera genome [organism]']]}
# -------------------
# {'65306': [['**CO/NF-Y complex [protein complex]**', 'CO/NF-Y heterotrimers [protein complex]', 'CO/NF-Y structure [protein complex]'], ['Hd1/NF-Y complexes [protein complex]'], ['NF-YB/NF-YC dimer [protein complex]'], ['NF-YA-YB-CO trimer [protein complex]'], ['**CO/NF-YB/NF-YC trimer complex [protein complex]**', 'trimer structure of NF-YB-YC-CO [protein complex]'], ['PIF4-NF-YB9 complex [protein complex]'], ['NF-TOC1 [protein complex]'], ['NF-YCs [protein complex]']]}
# -------------------

# %% [markdown]
# ## Submit this file to batchapi in the playground

# %%
import jsonlines
import json
output_path = '/'
out_file = 'Users/manojitharajula/Documents/PhD/Connectome/Entity_disambiguation/kmeans/o3mini_val_ins/o3minihigh_1k_outs.jsonl'
with jsonlines.open(output_path + out_file, mode='w') as file:
    for i, chunk in enumerate(chunks):
        
        line = {
            "custom_id": str(i),
            "method": "POST",
            "url": "/v1/chat/completions",
            "body": {
                "model": "o3-mini",
                #"temperature": 0, #Enable this for non-reasoning model
                #"top_p": 0, #Enable this for non-reasoning model
                #"frequency_penalty": 0, #Enable this for non-reasoning model
                #"presence_penalty": 0, #Enable this for non-reasoning model
                "response_format": {"type": "json_object"},
                "messages": [
                    {
                        "role": "system",
                        "content": constant_system_message
                    },
                    {
                        "role": "user",
                        "content": constant_user_message
                    },
                    {
                        "role": "user",
                        "content": json.dumps(chunk, separators=(',', ':'))
                    }
                ],
                "reasoning_effort": "high"  # Options: "low", "medium", "high" (only for reasoning models)
                #"max_tokens": 16384 #Enable this for non-reasoning model
            }
        }
        file.write(line)
        #print(f'Wrote chunk {i+1} to file')




print('done writing to jsonl file')
# Out:
# done writing to jsonl file

# %% [markdown]
# ## Read the batchapi output file and convert it to csv

# %%
import json
import jsonlines
import csv
# output CSV file from .json file
skip_lines = 0
input_file = "./o3mini_val_outs/batch_67c1822ff1e081908a02fc175e749f0b_output.jsonl" # input batch jsonl output file from GPT
output_csv = "./o3mini_val_outs/o3mini_1k.csv"
with jsonlines.open(input_file) as reader, open(output_csv, mode="w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)

    writer.writerow(["cluster_id","is_correct", "user_prompt", "clusters"])
    for line in reader:
        # Navigate into the response body
        try:
            body = line["response"]["body"]
            # Get the JSON string from the assistant's "content"
            content_str = body["choices"][0]["message"]["content"]
            data = json.loads(content_str)
            for cluster_id, cluster_data in data.items():
                # Ensure cluster_data is a dictionary before accessing keys
                if not isinstance(cluster_data, dict):
                    print(f"Skipping: cluster_data for {cluster_id} is not a dictionary ->", cluster_data)
                    continue

                # Extract values safely
                is_correct = cluster_data.get("is_correct", "N/A")  # Default to "N/A" if missing
                user_prompt = cluster_data.get("user_prompt", "N/A")
                clusters = json.dumps(cluster_data.get("clusters", []), ensure_ascii=False)

                writer.writerow([cluster_id, is_correct, user_prompt, clusters])


            
            

        except (KeyError, IndexError, json.JSONDecodeError):
            # Skip lines that don't match the expected structure
            print("Skipping line:", line)
            skip_lines += 1
            print(line["response"]["body"]["choices"][0]["message"]["content"])
            pass
print(f"Skipped {skip_lines} lines")
# Out:
# Skipped 0 lines

# %% [markdown]
# ## Creating jsonl file for O3mini validation (V5)

# %%
#This is a script that loads a pandas dataframe from csv, converts the string formatted as a list into a list of lists. The list of lists is then flattened into a single list.

import pandas as pd
import random
import json
df = pd.read_csv('./gpt_final_outs/o3mini_maxclust_80_subset_random_1000_nocutoff.csv', index_col=None)

#rename the column "Entity Name" to "Entity" and "Group Items" to "output"
df = df.rename(columns={"Group Items": "Output"})

# Convert the string formatted as a list into a list of lists
df['Output'] = df['Output'].apply(lambda x: eval(x))

# Flatten the list of lists into a single list
df['Input'] = df['Output'].apply(lambda x: [item.strip("*") for sublist in x for item in sublist])

#randomize the order of the single list
df['Input'] = df['Input'].apply(lambda x: random.sample(x, len(x)))
#df = df[df['Input'].apply(len) < 30]
# make a new column, where internal lists of length 1 are removed 
df['Output>1'] = df['Output'].apply(lambda x: [item for item in x if len(item) > 1])
#create a flag column by name one_item. For each row in Output column, If length of the list in output column is less than 2, put True otherwise False.
df['one_item'] = df['Output>1'].apply(lambda x: True if len(x) == 0 else False)

#zip the Group_Items_no_singles with the Entity Name 
df["Output"] = df.apply(lambda row: {row["Entity Name"]: row['Output']}, axis=1)
df["Input"] = df.apply(lambda row: {row["Entity Name"]: row['Input']}, axis=1)
df['Output>1'] = df.apply(lambda row: {row["Entity Name"]: row['Output>1']}, axis=1)





#convert the columns to json strings
df["Output"] = df["Output"].apply(lambda x: json.dumps(x) if isinstance(x, dict) else x)
df["Input"] = df["Input"].apply(lambda x: json.dumps(x) if isinstance(x, dict) else x)
df["Output>1"] = df["Output>1"].apply(lambda x: json.dumps(x) if isinstance(x, dict) else x)

#Change order of columns to have input, then output, then output>1, then entity name
df = df[['Entity Name', 'Input', 'Output', 'Output>1', 'one_item']]

#filter by Output>1 length of the list > 1
#use column Output, but use only the ones where it clusteres multiple items together

# %%
#read output csv file
#load the  csv file
output_csv = pd.read_csv("./o3mini_val_outs/o3mini_1k.csv")

# %%
#create a dictionary with key as cluster_id and value as the clusters
o3_correct_cluster_dict = {}
for index, row in output_csv.iterrows():
    o3_correct_cluster_dict[row['cluster_id']] = row['clusters']

#create a new column named o3_corrected_cluster in df
df['o3_corrected_cluster'] = df['Entity Name'].map(o3_correct_cluster_dict)

# %%
variable_o3mini_corrected_cluster_enitity_dict =  df.set_index('Entity Name')['o3_corrected_cluster'].to_dict()
chunks_variable_o3mini_corrected_cluster = split_dict(variable_o3mini_corrected_cluster_enitity_dict,1)

# %%
variable_o3mini_corrected_cluster_dict = {}
for d in chunks_variable_o3mini_corrected_cluster:
    variable_o3mini_corrected_cluster_dict.update(d)

# %%
detailed_description = """
Input-1

{
  "0": [
    "meiotic arrest [phenotype]",
    "delayed/arrested meiosis [phenotype]",
    "absence of meiotic arrest [phenotype]",
    "meiotic prophase arrest [phenotype]",
    "males arresting in the middle of prophase I [phenotype]",
    "early arrest [phenotype]",
    "leptotene arrest [phenotype]",
    "pachytene arrest [phenotype]",
    "arrest in late prophase I [phenotype]",
    "meiosis I arrest [phenotype]",
    "meiotic arrest at telophase I [phenotype]",
    "male meiosis until the end of the first division [phenotype]",
    "termination of meiosis after anaphase I [phenotype]",
    "meiotic arrest in anaphase II [phenotype]",
    "arrested zygotic divisions [phenotype]",
    "arrested endosperm nuclear divisions [phenotype]",
    "arrest of the first mitotic division in gametogenesis [phenotype]",
    "arresting prior to the first mitotic division [phenotype]",
    "mitotic arrest during female gametogenesis [phenotype]"
  ]
}

Clustered entities given input-1:

{
  "0": [
    [
      "Meiotic block [phenotype]",
      "**meiotic arrest [phenotype]**",
      "meiotic arrest phenotype [phenotype]",
      "meiotic division stop [phenotype]"
    ],
    [
      "block in meiosis prophase I [phenotype]",
      "**meiotic prophase arrest [phenotype]**"
    ],
    [
      "**pachytene arrest [phenotype]**",
      "meiotic arrest at pachytene [phenotype]"
    ],
    [
      "arrest at the end of meiosis I [phenotype]",
      "arrest after meiosis I [phenotype]",
      "**meiotic arrest at telophase I [phenotype]**"
    ],
    [
      "**termination of meiosis after anaphase I [phenotype]**",
      "premature termination of meiosis after anaphase I [phenotype]"
    ],
    [
      "arrest of meiotic progression in anaphase II [phenotype]",
      "**meiotic arrest in anaphase II [phenotype]**"
    ],
    [
      "arresting the first mitosis during gametogenesis [phenotype]",
      "**arrest of the first mitotic division in gametogenesis [phenotype]**",
      "FNM half-stop [phenotype]"
    ]
  ]
}

Output-1:
{
  "0": {
    "reasoning": "All synonyms describing a complete, generic meiotic halt were clustered under **'meiotic arrest [phenotype]'**, chosen as the representative because it is concise and universally recognized. Broader prophase I arrests merged into **'meiotic prophase arrest [phenotype]'**, selected for its succinct coverage of any block in prophase I. Pachytene-specific arrests were grouped under **'pachytene arrest [phenotype]'**, chosen for clarity and direct reference to the fully synapsed stage. Arrests at the end of meiosis I appear under **'meiotic arrest at telophase I [phenotype]'**, precisely indicating telophase I. Post-anaphase I failures were combined into **'termination of meiosis after anaphase I [phenotype]'**, spotlighting the exact point of cessation. Anaphase II stalls were labeled **'meiotic arrest in anaphase II [phenotype]'**, pinpointing the second division stage. Finally, blocks in the first post-meiotic mitosis formed the cluster **'arrest of the first mitotic division in gametogenesis [phenotype]'**, chosen for its explicit naming of that specific cell-cycle event. Single-term categories (e.g., 'delayed/arrested meiosis [phenotype]', 'absence of meiotic arrest [phenotype]') remain excluded from the final output."
  }
}


Input-2
{
  "2": '[
    "Salt-stress severity [treatment]",
    "high NaCl stress [treatment]",
    "potassium deprivation stress [treatment]",
    "salt-stress response [treatment]",
    "salt stress tolerance [treatment]",
    "heat and salt stress conditions [treatment]",
    "prolonged levels of salt stress [treatment]",
    "recovery from salt stress [treatment]",
    "salt stress assay [treatment]",
    "salt stress signaling pathways [treatment]",
    "gradual salt stress treatments [treatment]",
    "salt and low temperature stresses [treatment]",
    "salt and silicon stresses [treatment]"
  ]'
}

clustered entities for given input-2
{
  "2": [
    [
      "Salt-stress severity [treatment]",
      "**high NaCl stress [treatment]**",
      "salt-stress response [treatment]",
      "salt stress tolerance [treatment]",
      "prolonged levels of salt stress [treatment]",
      "recovery from salt stress [treatment]",
      "salt stress assay [treatment]",
      "salt stress signaling pathways [treatment]",
      "gradual salt stress treatments [treatment]"
    ]
  ]
}

Output-2:
{'2':{'reasoning':'All treatments that involve only salt (NaCl)––such as “Salt-stress severity,” “salt-stress response,” “salt stress tolerance,” “prolonged levels of salt stress,” “recovery from salt stress,” “salt stress assay,” “salt stress signaling pathways,” “gradual salt stress treatments,” and “high NaCl stress”––cluster together, because each focuses on the same abiotic stress factor (NaCl). They appear in the final output under the representative “**high NaCl stress [treatment]**”. In contrast, single-term items that mix salt with another factor (e.g., heat, low temperature, or silicon) or that involve a completely different stress (e.g., potassium deprivation) remain separate clusters of length one and thus are omitted from the output.'}}

"""

# %%
import jsonlines
import json
output_path = '/Users/manojitharajula/Documents/PhD/Connectome/Entity_disambiguation/kmeans/o3mini_val_ins/o3minihigh_v2_1k_outs.jsonl'
with jsonlines.open(output_path, mode='w') as file:
    for i in range(len(chunks_variable_input_entity)):
    
        line = {
            "custom_id": str(i),
            "method": "POST",
            "url": "/v1/chat/completions",
            "body": {
                "model": "o3-mini",
                #"temperature": 0, #Enable this for non-reasoning model
                #"top_p": 0, #Enable this for non-reasoning model
                #"frequency_penalty": 0, #Enable this for non-reasoning model
                #"presence_penalty": 0, #Enable this for non-reasoning model
                "response_format": {"type": "json_object"},
                "messages": [
                    {
                        "role": "system",
                        "content": system_message
                    },
                    {
                        "role": "user",
                        "content": detailed_description
                    },
                    {
                        "role": "user",
                        "content": json.dumps(chunks_variable_input_entity[i], indent=2)
                    }
                ],
                "reasoning_effort": "high"  # Options: "low", "medium", "high" (only for reasoning models)
                #"max_tokens": 16384 #Enable this for non-reasoning model
            }
        }
        file.write(line)
        #print(f'Wrote chunk {i+1} to file')




print('done writing to {} file'.format(output_path))

# %% [markdown]
# ## Read the output jsonl file and convert it to csv file

# %%
import json
import jsonlines
import csv
# output CSV file from .json file
skip_lines = 0
input_file = "./o3mini_val_outs/batch_67c58e5895ec81909dfeaea04841b738_output.jsonl" # input batch jsonl output file from GPT
output_csv = "./o3mini_val_outs/o3mini_1k_v2_again.csv"
with jsonlines.open(input_file) as reader, open(output_csv, mode="w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)

    writer.writerow(["cluster_id","reasoning"])
    for line in reader:
        # Navigate into the response body
        try:
            body = line["response"]["body"]
            # Get the JSON string from the assistant's "content"
            content_str = body["choices"][0]["message"]["content"]
            data = json.loads(content_str)
            for cluster_id, cluster_data in data.items():
                #if int(cluster_id) not in empty_keys:
                reasoning = cluster_data.get("reasoning")
                writer.writerow([cluster_id, reasoning])


            
            

        except (KeyError, IndexError, json.JSONDecodeError):
            # Skip lines that don't match the expected structure
            print("Skipping line:", line)
            skip_lines += 1
            print(line["response"]["body"]["choices"][0]["message"]["content"])
            pass
print(f"Skipped {skip_lines} lines")
